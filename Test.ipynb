# %%
from dotenv import load_dotenv
import os
from FeaturesGetterModule.FeaturesGetter import FeaturesGetter
import numpy as np

load_dotenv("dev.env")
API_KEY = os.getenv("COINGLASS_API_KEY")

if not API_KEY:
    raise ValueError("COINGLASS_API_KEY not found in dev.env")

# Создаём экземпляр FeaturesGetter
getter = FeaturesGetter(api_key=API_KEY)

import pandas as pd

# Показывать все колонки
pd.set_option('display.max_columns', None)

# Опционально: не обрезать ширину колонок
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Checking features (and comparing to YurasCode)

# %%
df_oi = getter.get_history(endpoint_name="open_interest_history")
rows, cols = df_oi.shape
print(f"Строк: {rows}, Столбцов: {cols}")
# Out:
# Строк: 1000, Столбцов: 5

# %%
df_oi_agg = getter.get_history(endpoint_name="open_interest_aggregated")
rows, cols = df_oi_agg.shape
print(f"Строк: {rows}, Столбцов: {cols}")
# Out:
# Строк: 1000, Столбцов: 5

# %%
df_oi_stable_coin = getter.get_history(endpoint_name="open_interest_stablecoin")
rows, cols = df_oi_stable_coin.shape
print(f"Строк: {rows}, Столбцов: {cols}")
# Out:
# Строк: 1000, Столбцов: 5

# %%
df_rate_history = getter.get_history(endpoint_name="funding_rate_history")
rows, cols = df_rate_history.shape
print(f"Строк: {rows}, Столбцов: {cols}")
# Out:
# Строк: 1000, Столбцов: 5

# %%
df_funding_rate_oi_weight = getter.get_history(endpoint_name="funding_rate_oi_weight")
rows, cols = df_funding_rate_oi_weight.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_funding_rate_oi_weight.tail()
# Out:
# Строк: 1000, Столбцов: 5
#      funding_rate_oi_weight__open  funding_rate_oi_weight__high  \
# 995                     -0.001888                      0.004545
# 996                      0.004545                      0.007071
# 997                      0.003044                      0.005962
# 998                      0.004012                      0.008487
# 999                      0.004100                      0.006046
#
#      funding_rate_oi_weight__low  funding_rate_oi_weight__close        date
# 995                    -0.004887                       0.004545  2026-01-15
# 996                     0.002580                       0.003044  2026-01-16
# 997                     0.000215                       0.004012  2026-01-17
# 998                     0.003429                       0.004201  2026-01-18
# 999                     0.003868                       0.004992  2026-01-19

# %%
df_funding_rate_vol_weight = getter.get_history(endpoint_name="funding_rate_vol_weight", prefix="feature_" + "funding_rate_vol_weight")
rows, cols = df_funding_rate_vol_weight.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_funding_rate_vol_weight.tail()
# Out:
# Строк: 1000, Столбцов: 5
#      feature_funding_rate_vol_weight__open  \
# 995                              -0.002744
# 996                               0.003279
# 997                               0.001963
# 998                               0.003641
# 999                               0.003413
#
#      feature_funding_rate_vol_weight__high  \
# 995                               0.004478
# 996                               0.006154
# 997                               0.005629
# 998                               0.008404
# 999                               0.003413
#
#      feature_funding_rate_vol_weight__low  \
# 995                             -0.004511
# 996                              0.001963
# 997                             -0.000284
# 998                              0.002763
# 999                              0.003413
#
#      feature_funding_rate_vol_weight__close        date
# 995                                0.003279  2026-01-15
# 996                                0.001963  2026-01-16
# 997                                0.003641  2026-01-17
# 998                                0.003413  2026-01-18
# 999                                0.003413  2026-01-19

# %%
df_global_long_short_account_ratio = getter.get_history(endpoint_name="global_long_short_account_ratio", prefix="feature")
rows, cols = df_global_long_short_account_ratio.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_global_long_short_account_ratio.tail()
# Out:
# Строк: 1000, Столбцов: 4
#      feature__global_account_long_percent  \
# 995                                 46.68
# 996                                 53.32
# 997                                 56.43
# 998                                 57.65
# 999                                 66.43
#
#      feature__global_account_short_percent  \
# 995                                  53.32
# 996                                  46.68
# 997                                  43.57
# 998                                  42.35
# 999                                  33.57
#
#      feature__global_account_long_short_ratio        date
# 995                                      0.88  2026-01-15
# 996                                      1.14  2026-01-16
# 997                                      1.30  2026-01-17
# 998                                      1.36  2026-01-18
# 999                                      1.98  2026-01-19

# %%
df_top_long_short_account_ratio = getter.get_history(endpoint_name="top_long_short_account_ratio", prefix="feature")
rows, cols = df_top_long_short_account_ratio.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_top_long_short_account_ratio.tail()
# Out:
# Строк: 1000, Столбцов: 4
#      feature__top_account_long_percent  feature__top_account_short_percent  \
# 995                              50.45                               49.55
# 996                              57.11                               42.89
# 997                              59.43                               40.57
# 998                              60.62                               39.38
# 999                              68.70                               31.30
#
#      feature__top_account_long_short_ratio        date
# 995                                   1.02  2026-01-15
# 996                                   1.33  2026-01-16
# 997                                   1.47  2026-01-17
# 998                                   1.54  2026-01-18
# 999                                   2.20  2026-01-19

# %%
df_top_long_short_position_ratio = getter.get_history(endpoint_name="top_long_short_position_ratio", prefix="feature")
rows, cols = df_top_long_short_position_ratio.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_top_long_short_position_ratio.tail()
# Out:
# Строк: 1000, Столбцов: 4
#      feature__top_position_long_percent  feature__top_position_short_percent  \
# 995                               62.74                                37.26
# 996                               66.62                                33.38
# 997                               66.23                                33.77
# 998                               67.15                                32.85
# 999                               68.20                                31.80
#
#      feature__top_position_long_short_ratio        date
# 995                                    1.68  2026-01-15
# 996                                    2.00  2026-01-16
# 997                                    1.96  2026-01-17
# 998                                    2.04  2026-01-18
# 999                                    2.15  2026-01-19

# %%
df_net_pos = getter.get_history(endpoint_name="net_position", prefix="feature")
rows, cols = df_net_pos.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_net_pos.tail()
# Out:
# Строк: 1000, Столбцов: 3
#      feature__net_long_change  feature__net_short_change        date
# 995                 1598.3650                 -1148.0250  2026-01-15
# 996                -3606.1295                   932.6695  2026-01-16
# 997                  108.8350                  1290.0250  2026-01-17
# 998                 -926.4995                   555.5795  2026-01-18
# 999                -1637.4490                 -1704.7650  2026-01-19

# %%
df_liqidation_history = getter.get_history(endpoint_name="liquidation_history", prefix="feature")
rows, cols = df_liqidation_history.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_liqidation_history.tail()
# Out:
# Строк: 1000, Столбцов: 3
#      feature__long_liquidation_usd  feature__short_liquidation_usd        date
# 995                   5.676166e+06                    4.301004e+06  2026-01-15
# 996                   2.941486e+06                    1.762504e+06  2026-01-16
# 997                   8.299577e+05                    9.511745e+05  2026-01-17
# 998                   6.942629e+06                    9.089290e+05  2026-01-18
# 999                   8.133955e+06                    2.099568e+06  2026-01-19

# %%
df_liqidation_history = getter.get_history(endpoint_name="liquidation_aggregated", prefix="feature")
rows, cols = df_liqidation_history.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_liqidation_history.tail()
# Out:
# Строк: 1000, Столбцов: 3
#      feature__aggregated_long_liquidation_usd  \
# 995                              7.087470e+06
# 996                              3.380796e+06
# 997                              8.898883e+05
# 998                              8.002196e+06
# 999                              1.107603e+07
#
#      feature__aggregated_short_liquidation_usd        date
# 995                               4.623421e+06  2026-01-15
# 996                               1.874804e+06  2026-01-16
# 997                               1.008533e+06  2026-01-17
# 998                               1.085174e+06  2026-01-18
# 999                               2.508005e+06  2026-01-19

# %%
df_orderbook_ask_bids = getter.get_history(endpoint_name="orderbook_ask_bids", prefix="feature")
rows, cols = df_orderbook_ask_bids.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_orderbook_ask_bids.tail()
# Out:
# Строк: 635, Столбцов: 5
#      feature__bids_usd  feature__bids_quantity  feature__asks_usd  \
# 630       1.353054e+08                1402.029       9.393401e+07
# 631       1.784007e+08                1875.911       1.296571e+08
# 632       1.276909e+08                1342.669       1.883437e+08
# 633       2.543666e+08                2688.808       1.764464e+08
# 634       1.774146e+08                1915.656       1.667345e+08
#
#      feature__asks_quantity        date
# 630                 965.810  2026-01-15
# 631                1351.176  2026-01-16
# 632                1964.155  2026-01-17
# 633                1846.565  2026-01-18
# 634                1784.655  2026-01-19

# %%
df_orderbook_aggregated = getter.get_history(endpoint_name="orderbook_aggregated", prefix="feature")
rows, cols = df_orderbook_aggregated.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_orderbook_aggregated.tail()
# Out:
# Строк: 635, Столбцов: 5
#      feature__aggregated_bids_usd  feature__aggregated_bids_quantity  \
# 630                  1.353054e+08                           1402.029
# 631                  1.784007e+08                           1875.911
# 632                  1.276909e+08                           1342.669
# 633                  2.543666e+08                           2688.808
# 634                  1.867916e+08                           2016.866
#
#      feature__aggregated_asks_usd  feature__aggregated_asks_quantity  \
# 630                  9.393401e+07                            965.810
# 631                  1.296571e+08                           1351.176
# 632                  1.883437e+08                           1964.155
# 633                  1.764464e+08                           1846.565
# 634                  1.760569e+08                           1884.488
#
#            date
# 630  2026-01-15
# 631  2026-01-16
# 632  2026-01-17
# 633  2026-01-18
# 634  2026-01-19

# %%
df_taker_buy_sell_volume = getter.get_history(endpoint_name="taker_buy_sell_volume", prefix="feature")
rows, cols = df_taker_buy_sell_volume.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_taker_buy_sell_volume.tail()
# Out:
# Строк: 1000, Столбцов: 3
#      feature__taker_buy_volume_usd  feature__taker_sell_volume_usd        date
# 995                   7.310207e+09                    7.044570e+09  2026-01-15
# 996                   4.600541e+09                    5.031243e+09  2026-01-16
# 997                   1.799159e+09                    1.911601e+09  2026-01-17
# 998                   2.897470e+09                    3.035915e+09  2026-01-18
# 999                   4.365836e+09                    4.359649e+09  2026-01-19

# %%
df_bitcoin_lth_supply = getter.get_bitcoin_lth_supply(prefix="feature_" + "bitcoin_lth_supply")
rows, cols = df_bitcoin_lth_supply.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_bitcoin_lth_supply.tail()
# Out:
# Строк: 5267, Столбцов: 6
#             date  feature_bitcoin_lth_supply__price  \
# 5262  2026-01-14                            97008.0
# 5263  2026-01-15                            95585.0
# 5264  2026-01-16                            95516.0
# 5265  2026-01-17                            95100.0
# 5266  2026-01-18                            93753.0
#
#       feature_bitcoin_lth_supply__lth_supply  \
# 5262                            1.408793e+07
# 5263                            1.409609e+07
# 5264                            1.412253e+07
# 5265                            1.414097e+07
# 5266                            1.414158e+07
#
#       feature_bitcoin_lth_supply__supply_pct30  \
# 5262                                  0.004471
# 5263                                  0.005179
# 5264                                  0.007060
# 5265                                  0.007259
# 5266                                  0.006081
#
#       feature_bitcoin_lth_supply__supply_z180  \
# 5262                                -1.426722
# 5263                                -1.396726
# 5264                                -1.338588
# 5265                                -1.294035
# 5266                                -1.278217
#
#       feature_bitcoin_lth_supply__supply_slope14
# 5262                                  715.343671
# 5263                                 1489.770476
# 5264                                 2853.429168
# 5265                                 3263.027330
# 5266                                 3299.893078

# %%
df_get_bitcoin_active_addresses = getter.get_bitcoin_active_addresses(prefix="feature_" + "get_bitcoin_active_addresses")
rows, cols = df_get_bitcoin_active_addresses.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_get_bitcoin_active_addresses.tail()
# Out:
# Строк: 5634, Столбцов: 6
#             date  feature_get_bitcoin_active_addresses__price  \
# 5629  2026-01-14                                 95322.908608
# 5630  2026-01-15                                 96931.291383
# 5631  2026-01-16                                 95554.099561
# 5632  2026-01-17                                 95525.156843
# 5633  2026-01-18                                 95101.178945
#
#       feature_get_bitcoin_active_addresses__active_address_count  \
# 5629                                                      725683
# 5630                                                      727968
# 5631                                                      692650
# 5632                                                      604794
# 5633                                                      551983
#
#       feature_get_bitcoin_active_addresses__aa_pct7  \
# 5629                                       0.120087
# 5630                                       0.160745
# 5631                                       0.016694
# 5632                                       0.001892
# 5633                                      -0.001413
#
#       feature_get_bitcoin_active_addresses__aa_z180  \
# 5629                                       0.286625
# 5630                                       0.314819
# 5631                                      -0.213695
# 5632                                      -1.500666
# 5633                                      -2.236083
#
#       feature_get_bitcoin_active_addresses__aa_slope14
# 5629                                        850.000000
# 5630                                       9929.500000
# 5631                                        218.571429
# 5632                                      -2437.714286
# 5633                                      -5124.000000

# %%
df_get_bitcoin_sth_supply = getter.get_bitcoin_sth_supply(prefix="feature_" + "get_bitcoin_sth_supply")
rows, cols = df_get_bitcoin_sth_supply.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_get_bitcoin_sth_supply.tail()
# Out:
# Строк: 5267, Столбцов: 6
#             date  feature_get_bitcoin_sth_supply__price  \
# 5262  2026-01-14                                97008.0
# 5263  2026-01-15                                95585.0
# 5264  2026-01-16                                95516.0
# 5265  2026-01-17                                95100.0
# 5266  2026-01-18                                93753.0
#
#       feature_get_bitcoin_sth_supply__sth_supply  \
# 5262                                5.887989e+06
# 5263                                5.880261e+06
# 5264                                5.854234e+06
# 5265                                5.836255e+06
# 5266                                5.836088e+06
#
#       feature_get_bitcoin_sth_supply__supply_pct30  \
# 5262                                     -0.008321
# 5263                                     -0.009992
# 5264                                     -0.014436
# 5265                                     -0.014960
# 5266                                     -0.012225
#
#       feature_get_bitcoin_sth_supply__supply_z180  \
# 5262                                     1.440250
# 5263                                     1.411186
# 5264                                     1.354913
# 5265                                     1.311860
# 5266                                     1.296515
#
#       feature_get_bitcoin_sth_supply__supply_slope14
# 5262                                     -277.174028
# 5263                                    -1054.279405
# 5264                                    -2421.063097
# 5265                                    -2832.000544
# 5266                                    -2869.982364

# %%
df_taker_buy_sell_volume_aggregated = getter.get_history(endpoint_name="taker_buy_sell_volume_aggregated", prefix="feature")
rows, cols = df_taker_buy_sell_volume_aggregated.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_taker_buy_sell_volume_aggregated.tail()
# Out:
# Строк: 1000, Столбцов: 3
#      feature__aggregated_buy_volume_usd  feature__aggregated_sell_volume_usd  \
# 995                        9.429214e+09                         9.118295e+09
# 996                        5.880402e+09                         6.402439e+09
# 997                        2.291735e+09                         2.457957e+09
# 998                        3.624064e+09                         3.810049e+09
# 999                        5.784316e+09                         5.690437e+09
#
#            date
# 995  2026-01-15
# 996  2026-01-16
# 997  2026-01-17
# 998  2026-01-18
# 999  2026-01-19

# %%
df_get_bitfinex_margin_long_short = getter.get_bitfinex_margin_long_short(prefix="feature_" + "bitfinex_margin_long_short")
rows, cols = df_get_bitfinex_margin_long_short.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_get_bitfinex_margin_long_short.tail()
# Out:
# Строк: 1000, Столбцов: 6
#            date  feature_bitfinex_margin_long_short__long_quantity  \
# 995  2026-01-15                                           70852.62
# 996  2026-01-16                                           70723.03
# 997  2026-01-17                                           70649.62
# 998  2026-01-18                                           70638.44
# 999  2026-01-19                                           70698.63
#
#      feature_bitfinex_margin_long_short__short_quantity  \
# 995                                              171.43
# 996                                              175.76
# 997                                              187.18
# 998                                              175.87
# 999                                              190.37
#
#      feature_bitfinex_margin_long_short__total_qty  \
# 995                                       71024.05
# 996                                       70898.79
# 997                                       70836.80
# 998                                       70814.31
# 999                                       70889.00
#
#      feature_bitfinex_margin_long_short__long_share  \
# 995                                        0.997586
# 996                                        0.997521
# 997                                        0.997358
# 998                                        0.997516
# 999                                        0.997315
#
#      feature_bitfinex_margin_long_short__log_long_short
# 995                                            6.024182
# 996                                            5.997407
# 997                                            5.933417
# 998                                            5.995585
# 999                                            5.917212

# %%
df_cgdi_index = getter.get_cgdi_index(prefix="feature_" + "cgdi_index")
rows, cols = df_cgdi_index.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_cgdi_index.tail()
# Out:
# Строк: 750, Столбцов: 5
#            date  feature_cgdi_index__index_value  \
# 745  2026-01-15                        2263.1878
# 746  2026-01-16                        2172.2652
# 747  2026-01-17                        2159.3674
# 748  2026-01-18                        2171.4726
# 749  2026-01-19                        2086.8309
#
#      feature_cgdi_index__log_level  feature_cgdi_index__dev_from_base  \
# 745                       7.724530                          1263.1878
# 746                       7.683526                          1172.2652
# 747                       7.677571                          1159.3674
# 748                       7.683161                          1171.4726
# 749                       7.643402                          1086.8309
#
#      feature_cgdi_index__dev_softsign
# 745                          0.558145
# 746                          0.539651
# 747                          0.536901
# 748                          0.539483
# 749                          0.520804

# %%
df_coinbase_premium_index = getter.get_coinbase_premium_index(prefix="feature_" + "coinbase_premium_index")
rows, cols = df_coinbase_premium_index.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_coinbase_premium_index.tail()
# Out:
# Строк: 1000, Столбцов: 7
#            date  feature_coinbase_premium_index__premium  \
# 995  2026-01-15                                     2.23
# 996  2026-01-16                                   -26.61
# 997  2026-01-17                                   -46.94
# 998  2026-01-18                                   -37.78
# 999  2026-01-19                                   -43.14
#
#      feature_coinbase_premium_index__premium_rate  \
# 995                                        0.0023
# 996                                       -0.0278
# 997                                       -0.0491
# 998                                       -0.0397
# 999                                       -0.0461
#
#      feature_coinbase_premium_index__premium_abs  \
# 995                                         2.23
# 996                                        26.61
# 997                                        46.94
# 998                                        37.78
# 999                                        43.14
#
#      feature_coinbase_premium_index__premium_softsign  \
# 995                                          0.690402
# 996                                         -0.963781
# 997                                         -0.979141
# 998                                         -0.974214
# 999                                         -0.977345
#
#      feature_coinbase_premium_index__premium_rate_bps  \
# 995                                              23.0
# 996                                            -278.0
# 997                                            -491.0
# 998                                            -397.0
# 999                                            -461.0
#
#      feature_coinbase_premium_index__implied_ref_price
# 995                                       96956.479584
# 996                                       95719.427904
# 997                                       95600.816611
# 998                                       95163.730357
# 999                                       93579.177735

# %%
df_get_bitcoin_reserve_risk = getter.get_bitcoin_reserve_risk(prefix="feature_" + "get_bitcoin_reserve_risk")
rows, cols = df_get_bitcoin_reserve_risk.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_get_bitcoin_reserve_risk.tail()
# Out:
# Строк: 5633, Столбцов: 9
#             date  feature_get_bitcoin_reserve_risk__price  \
# 5628  2026-01-14                                  97008.0
# 5629  2026-01-15                                  95585.0
# 5630  2026-01-16                                  95516.0
# 5631  2026-01-17                                  95100.0
# 5632  2026-01-18                                  93753.0
#
#       feature_get_bitcoin_reserve_risk__reserve_risk_index  \
# 5628                                              0.001895
# 5629                                              0.001866
# 5630                                              0.001862
# 5631                                              0.001852
# 5632                                              0.001824
#
#       feature_get_bitcoin_reserve_risk__movcd  \
# 5628                             43713.491563
# 5629                             43713.491563
# 5630                             43042.446490
# 5631                             43042.446490
# 5632                             41063.868764
#
#       feature_get_bitcoin_reserve_risk__hodl_bank  \
# 5628                                 5.118568e+07
# 5629                                 5.123755e+07
# 5630                                 5.129003e+07
# 5631                                 5.134208e+07
# 5632                                 5.139477e+07
#
#       feature_get_bitcoin_reserve_risk__vocd  \
# 5628                            43982.901752
# 5629                            44225.755630
# 5630                            31162.637620
# 5631                            39486.925922
# 5632                            19153.014936
#
#       feature_get_bitcoin_reserve_risk__log_rr  \
# 5628                                 -6.268422
# 5629                                 -6.284212
# 5630                                 -6.285958
# 5631                                 -6.291337
# 5632                                 -6.306628
#
#       feature_get_bitcoin_reserve_risk__rr_z180  \
# 5628                                  -0.926951
# 5629                                  -1.012497
# 5630                                  -1.012045
# 5631                                  -1.033431
# 5632                                  -1.113849
#
#       feature_get_bitcoin_reserve_risk__rr_slope14
# 5628                                      0.000012
# 5629                                      0.000008
# 5630                                      0.000006
# 5631                                      0.000005
# 5632                                      0.000002

# %%
df_open_interest_coin_margin = getter.get_bitcoin_reserve_risk(prefix="feature_" + "open_interest_coin_margin")
rows, cols = df_open_interest_coin_margin.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_open_interest_coin_margin.tail()
# Out:
# Строк: 5633, Столбцов: 9
#             date  feature_open_interest_coin_margin__price  \
# 5628  2026-01-14                                   97008.0
# 5629  2026-01-15                                   95585.0
# 5630  2026-01-16                                   95516.0
# 5631  2026-01-17                                   95100.0
# 5632  2026-01-18                                   93753.0
#
#       feature_open_interest_coin_margin__reserve_risk_index  \
# 5628                                               0.001895
# 5629                                               0.001866
# 5630                                               0.001862
# 5631                                               0.001852
# 5632                                               0.001824
#
#       feature_open_interest_coin_margin__movcd  \
# 5628                              43713.491563
# 5629                              43713.491563
# 5630                              43042.446490
# 5631                              43042.446490
# 5632                              41063.868764
#
#       feature_open_interest_coin_margin__hodl_bank  \
# 5628                                  5.118568e+07
# 5629                                  5.123755e+07
# 5630                                  5.129003e+07
# 5631                                  5.134208e+07
# 5632                                  5.139477e+07
#
#       feature_open_interest_coin_margin__vocd  \
# 5628                             43982.901752
# 5629                             44225.755630
# 5630                             31162.637620
# 5631                             39486.925922
# 5632                             19153.014936
#
#       feature_open_interest_coin_margin__log_rr  \
# 5628                                  -6.268422
# 5629                                  -6.284212
# 5630                                  -6.285958
# 5631                                  -6.291337
# 5632                                  -6.306628
#
#       feature_open_interest_coin_margin__rr_z180  \
# 5628                                   -0.926951
# 5629                                   -1.012497
# 5630                                   -1.012045
# 5631                                   -1.033431
# 5632                                   -1.113849
#
#       feature_open_interest_coin_margin__rr_slope14
# 5628                                       0.000012
# 5629                                       0.000008
# 5630                                       0.000006
# 5631                                       0.000005
# 5632                                       0.000002

# %% [markdown]
# ## Merging features into one dataset by date

# %%
from Getting_and_preprocessing_features import fetch_all_coinglass_features, print_features_summary, merge_all_features

# Загружаем все фичи
print("Загрузка фичей с CoinGlass...")
features = fetch_all_coinglass_features(getter)

# Выводим сводку
print_features_summary(features)

# Объединяем в один DataFrame
print("\nОбъединение фичей...")
df_all = merge_all_features(features)

# Удаляем строки где нет данных по spot price (до ~2019 года)
df_all = df_all.dropna(subset=["feature_spot_price_history__close"]).reset_index(drop=True)
print(f"После dropna: {len(df_all)} записей, {len(df_all.columns)} колонок")

df_all.isna().sum()
# Out:
# Загрузка фичей с CoinGlass...
# ======================================================================
# СВОДКА ПО ЗАГРУЖЕННЫМ ФИЧАМ
# ======================================================================
#   open_interest_history: 1000 записей, 5 колонок, 2023-04-26 — 2026-01-19
#   open_interest_aggregated: 1000 записей, 5 колонок, 2023-04-26 — 2026-01-19
#   open_interest_stablecoin: 1000 записей, 5 колонок, 2023-04-26 — 2026-01-19
#   open_interest_coin_margin: 1000 записей, 5 колонок, 2023-04-26 — 2026-01-19
#   funding_rate_history: 1000 записей, 5 колонок, 2023-04-26 — 2026-01-19
#   funding_rate_oi_weight: 1000 записей, 5 колонок, 2023-04-26 — 2026-01-19
#   funding_rate_vol_weight: 1000 записей, 5 колонок, 2023-04-26 — 2026-01-19
#   global_long_short_account_ratio: 1000 записей, 4 колонок, 2023-04-26 — 2026-01-19
#   top_long_short_account_ratio: 1000 записей, 4 колонок, 2023-04-26 — 2026-01-19
#   top_long_short_position_ratio: 1000 записей, 4 колонок, 2023-04-26 — 2026-01-19
#   net_position: 1000 записей, 3 колонок, 2023-04-26 — 2026-01-19
#   liquidation_history: 1000 записей, 3 колонок, 2023-04-26 — 2026-01-19
#   liquidation_aggregated: 1000 записей, 3 колонок, 2023-04-26 — 2026-01-19
#   orderbook_ask_bids: 635 записей, 5 колонок, 2024-04-25 — 2026-01-19
#   orderbook_aggregated: 635 записей, 5 колонок, 2024-04-25 — 2026-01-19
#   taker_buy_sell_volume: 1000 записей, 3 колонок, 2023-04-26 — 2026-01-19
#   taker_buy_sell_volume_aggregated: 1000 записей, 3 колонок, 2023-04-26 — 2026-01-19
#   spot_price_history: 1000 записей, 6 колонок, 2023-04-26 — 2026-01-19
#   bitcoin_lth_supply: 5267 записей, 6 колонок, 2011-08-18 — 2026-01-18
#   bitcoin_active_addresses: 5634 записей, 6 колонок, 2010-08-17 — 2026-01-18
#   bitcoin_sth_supply: 5267 записей, 6 колонок, 2011-08-18 — 2026-01-18
#   bitcoin_reserve_risk: 5633 записей, 9 колонок, 2010-08-17 — 2026-01-18
#   bitfinex_margin_long_short: 1000 записей, 6 колонок, 2023-04-26 — 2026-01-19
#   coinbase_premium_index: 1000 записей, 7 колонок, 2023-04-26 — 2026-01-19
#   cgdi_index: 750 записей, 5 колонок, 2024-01-01 — 2026-01-19
# ======================================================================
#
# Объединение фичей...
# feature_open_interest_history__open                  4635
# feature_open_interest_history__high                  4635
# feature_open_interest_history__low                   4635
# feature_open_interest_history__close                 4635
# date                                                    0
#                                                      ...
# feature_coinbase_premium_index__implied_ref_price    4635
# feature_cgdi_index__index_value                      4885
# feature_cgdi_index__log_level                        4885
# feature_cgdi_index__dev_from_base                    4885
# feature_cgdi_index__dev_softsign                     4885
# Length: 99, dtype: int64

# %% [markdown]
# ## Adding traget column (the price has grown comparing to previous day or not?)

# %%
import pandas as pd

N_DAYS = 1

def add_y_up_1d(df: pd.DataFrame, close_col: str = "spot_price_history__close") -> pd.DataFrame:
    out = df.copy()
    out["date"] = pd.to_datetime(out["date"], errors="coerce")
    out = out.sort_values("date", kind="stable").reset_index(drop=True)

    c = pd.to_numeric(out[close_col], errors="coerce")
    out["y_up_1d"] = (c.shift(-1*N_DAYS) > c).astype("Int64")
    return out

df_all = add_y_up_1d(df_all, close_col="feature_spot_price_history__close")

df_all = df_all.dropna(subset=["y_up_1d", "feature_spot_price_history__close"]).reset_index(drop=True)

# Синтаксис: [все_строки, от_колонки_date : до_конца]
# df_all.loc[:, "date":]

# %%
import pandas as pd
import numpy as np

def add_engineered_features(df: pd.DataFrame) -> pd.DataFrame:
    # Сначала создаем список для новых колонок
    new_features = []
    
    # Список колонок для обработки
    base_numeric = [
        c for c in df.columns
        if c not in {"date", "y_up_1d"}
        and pd.api.types.is_numeric_dtype(df[c])
    ]
    
    # 1. Генерируем Diff и Pct (собираем их в список, НЕ вставляем в df сразу)
    for c in base_numeric:
        # Diff
        diff_col = df[c].diff(1)
        diff_col.name = c + "__diff1"  # Обязательно даем имя Series
        new_features.append(diff_col)
        
        # Pct
        pct_col = df[c].pct_change(1)
        pct_col.name = c + "__pct1"
        new_features.append(pct_col)
    
    # 2. Склеиваем всё разом (ОДНА операция вместо сотен)
    if new_features:
        # Создаем DataFrame из новых фичей
        df_new = pd.concat(new_features, axis=1)
        # Приклеиваем его к исходному
        out = pd.concat([df, df_new], axis=1)
    else:
        out = df.copy()

    # 3. Imbalances (их всего 4 штуки, тут вставка по одной не страшна)
    eps = 1e-12
    
    def _imbalance(num_col_a, num_col_b, new_col):
        # Проверяем наличие в out (теперь там есть и старые, и новые колонки)
        if num_col_a in out.columns and num_col_b in out.columns:
            a = pd.to_numeric(out[num_col_a], errors="coerce")
            b = pd.to_numeric(out[num_col_b], errors="coerce")
            out[new_col] = (a - b) / (a + b + eps)

    _imbalance(
        "futures_v2_taker_buy_sell_volume_history__taker_buy_volume_usd",
        "futures_v2_taker_buy_sell_volume_history__taker_sell_volume_usd",
        "feat__taker_imbalance_v2",
    )
    _imbalance(
        "futures_aggregated_taker_buy_sell_volume_history__aggregated_buy_volume_usd",
        "futures_aggregated_taker_buy_sell_volume_history__aggregated_sell_volume_usd",
        "feat__taker_imbalance_agg",
    )
    _imbalance(
        "futures_liquidation_history__short_liquidation_usd",
        "futures_liquidation_history__long_liquidation_usd",
        "feat__liq_imbalance_short_minus_long",
    )
    _imbalance(
        "futures_orderbook_ask_bids_history__bids_usd",
        "futures_orderbook_ask_bids_history__asks_usd",
        "feat__orderbook_imbalance_usd",
    )

    # 4. Чистим бесконечности
    out = out.replace([np.inf, -np.inf], np.nan)
    return out

# Вызов функции
df_all = add_engineered_features(df_all)

df_all
# Out:
# C:\Users\flays\AppData\Local\Temp\ipykernel_7376\756737255.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pct_col = df[c].pct_change(1)
#      feature_open_interest_history__open  feature_open_interest_history__high  \
# 0                           2.881445e+09                         3.213092e+09
# 1                           2.627379e+09                         2.950161e+09
# 2                           2.920234e+09                         3.032411e+09
# 3                           2.941302e+09                         3.032138e+09
# 4                           2.930743e+09                         3.134401e+09
# ..                                   ...                                  ...
# 995                         9.338724e+09                         9.439357e+09
# 996                         9.230233e+09                         9.273594e+09
# 997                         9.097467e+09                         9.132747e+09
# 998                         9.126077e+09                         9.325717e+09
# 999                         8.964468e+09                         8.964468e+09
#
#      feature_open_interest_history__low  feature_open_interest_history__close  \
# 0                          2.481298e+09                          2.627379e+09
# 1                          2.579601e+09                          2.920234e+09
# 2                          2.908663e+09                          2.941302e+09
# 3                          2.920526e+09                          2.930743e+09
# 4                          2.877234e+09                          2.877234e+09
# ..                                  ...                                   ...
# 995                        9.007947e+09                          9.230233e+09
# 996                        9.087243e+09                          9.097467e+09
# 997                        9.033789e+09                          9.126077e+09
# 998                        8.956025e+09                          8.964468e+09
# 999                        8.598500e+09                          8.753843e+09
#
#           date  feature_open_interest_aggregated__open  \
# 0   2023-04-26                            1.168441e+10
# 1   2023-04-27                            1.088542e+10
# 2   2023-04-28                            1.151240e+10
# 3   2023-04-29                            1.173963e+10
# 4   2023-04-30                            1.166303e+10
# ..         ...                                     ...
# 995 2026-01-15                            6.616826e+10
# 996 2026-01-16                            6.408110e+10
# 997 2026-01-17                            6.293181e+10
# 998 2026-01-18                            6.160500e+10
# 999 2026-01-19                            6.088417e+10
#
#      feature_open_interest_aggregated__high  \
# 0                              1.251776e+10
# 1                              1.175977e+10
# 2                              1.184306e+10
# 3                              1.187146e+10
# 4                              1.211516e+10
# ..                                      ...
# 995                            6.624105e+10
# 996                            6.418977e+10
# 997                            6.305444e+10
# 998                            6.217276e+10
# 999                            6.229033e+10
#
#      feature_open_interest_aggregated__low  \
# 0                             1.060145e+10
# 1                             1.078446e+10
# 2                             1.148081e+10
# 3                             9.703421e+09
# 4                             1.153806e+10
# ..                                     ...
# 995                           6.401553e+10
# 996                           6.194107e+10
# 997                           6.157379e+10
# 998                           6.077903e+10
# 999                           5.965149e+10
#
#      feature_open_interest_aggregated__close  \
# 0                               1.088542e+10
# 1                               1.151240e+10
# 2                               1.173963e+10
# 3                               1.166303e+10
# 4                               1.153806e+10
# ..                                       ...
# 995                             6.408110e+10
# 996                             6.293181e+10
# 997                             6.160500e+10
# 998                             6.088417e+10
# 999                             6.155815e+10
#
#      feature_open_interest_stablecoin__open  \
# 0                                 101865.37
# 1                                  92530.63
# 2                                  99128.75
# 3                                 100399.45
# 4                                 100323.92
# ..                                      ...
# 995                               107772.38
# 996                               107270.19
# 997                               105813.00
# 998                               106476.53
# 999                               104976.02
#
#      feature_open_interest_stablecoin__high  \
# 0                                 109129.24
# 1                                  99839.88
# 2                                 103610.78
# 3                                 103417.24
# 4                                 105280.87
# ..                                      ...
# 995                               109220.50
# 996                               108232.32
# 997                               106586.00
# 998                               108303.63
# 999                               105197.63
#
#      feature_open_interest_stablecoin__low  \
# 0                                 89962.48
# 1                                 89702.82
# 2                                 98939.07
# 3                                100036.39
# 4                                 98481.44
# ..                                     ...
# 995                              104790.86
# 996                              105646.17
# 997                              105363.39
# 998                              106193.63
# 999                              104584.86
#
#      feature_open_interest_stablecoin__close  \
# 0                                  92530.630
# 1                                  99128.750
# 2                                 100399.450
# 3                                 100323.920
# 4                                  98481.440
# ..                                       ...
# 995                               107270.190
# 996                               105813.000
# 997                               106476.530
# 998                               106353.500
# 999                               104801.179
#
#      feature_open_interest_coin_margin__open  \
# 0                               5.412750e+08
# 1                               5.219591e+08
# 2                               4.843472e+08
# 3                               4.840239e+08
# 4                               4.774026e+08
# ..                                       ...
# 995                             2.202317e+09
# 996                             2.109082e+09
# 997                             2.116094e+09
# 998                             2.152076e+09
# 999                             2.140944e+09
#
#      feature_open_interest_coin_margin__high  \
# 0                               5.507429e+08
# 1                               5.230934e+08
# 2                               4.940172e+08
# 3                               4.893262e+08
# 4                               4.869461e+08
# ..                                       ...
# 995                             2.206117e+09
# 996                             2.132463e+09
# 997                             2.161180e+09
# 998                             2.159383e+09
# 999                             2.173866e+09
#
#      feature_open_interest_coin_margin__low  \
# 0                              5.141669e+08
# 1                              4.802695e+08
# 2                              4.807856e+08
# 3                              4.746727e+08
# 4                              4.748471e+08
# ..                                      ...
# 995                            2.107219e+09
# 996                            2.108338e+09
# 997                            2.107625e+09
# 998                            2.133251e+09
# 999                            2.130022e+09
#
#      feature_open_interest_coin_margin__close  \
# 0                                5.219591e+08
# 1                                4.843472e+08
# 2                                4.840239e+08
# 3                                4.774026e+08
# 4                                4.809018e+08
# ..                                        ...
# 995                              2.109082e+09
# 996                              2.116094e+09
# 997                              2.152076e+09
# 998                              2.140944e+09
# 999                              2.132718e+09
#
#      feature_funding_rate_history__open  feature_funding_rate_history__high  \
# 0                              0.004390                            0.010000
# 1                              0.002518                            0.010000
# 2                              0.010000                            0.010000
# 3                              0.000086                            0.010000
# 4                              0.003152                            0.007717
# ..                                  ...                                 ...
# 995                           -0.000399                            0.008700
# 996                            0.007373                            0.010000
# 997                           -0.000183                            0.006697
# 998                            0.003502                            0.010000
# 999                            0.002370                            0.006011
#
#      feature_funding_rate_history__low  feature_funding_rate_history__close  \
# 0                            -0.003317                             0.002518
# 1                             0.001834                             0.010000
# 2                            -0.000005                             0.000086
# 3                            -0.000371                             0.003152
# 4                             0.002429                             0.002429
# ..                                 ...                                  ...
# 995                          -0.000654                             0.007373
# 996                          -0.000184                            -0.000183
# 997                          -0.000930                             0.003502
# 998                           0.003461                             0.003523
# 999                           0.002370                             0.006011
#
#      feature_funding_rate_oi_weight__open  \
# 0                                0.005083
# 1                                0.001396
# 2                                0.006322
# 3                               -0.000364
# 4                                0.002647
# ..                                    ...
# 995                             -0.001888
# 996                              0.004545
# 997                              0.003044
# 998                              0.004012
# 999                             -0.002778
#
#      feature_funding_rate_oi_weight__high  \
# 0                                0.011908
# 1                                0.007419
# 2                                0.009213
# 3                                0.005286
# 4                                0.009015
# ..                                    ...
# 995                              0.004545
# 996                              0.007071
# 997                              0.005962
# 998                              0.008487
# 999                              0.006046
#
#      feature_funding_rate_oi_weight__low  \
# 0                              -0.007245
# 1                              -0.001172
# 2                              -0.002456
# 3                              -0.007607
# 4                              -0.000833
# ..                                   ...
# 995                            -0.004887
# 996                             0.002580
# 997                             0.000215
# 998                             0.003429
# 999                            -0.006396
#
#      feature_funding_rate_oi_weight__close  \
# 0                                 0.001396
# 1                                 0.006322
# 2                                -0.000364
# 3                                 0.002647
# 4                                 0.003325
# ..                                     ...
# 995                               0.004545
# 996                               0.003044
# 997                               0.004012
# 998                               0.004201
# 999                               0.005241
#
#      feature_funding_rate_vol_weight__open  \
# 0                                 0.004514
# 1                                 0.001335
# 2                                 0.006673
# 3                                -0.000404
# 4                                 0.002456
# ..                                     ...
# 995                              -0.002744
# 996                               0.003279
# 997                               0.001963
# 998                               0.003641
# 999                               0.003413
#
#      feature_funding_rate_vol_weight__high  \
# 0                                 0.011725
# 1                                 0.007383
# 2                                 0.010006
# 3                                 0.007602
# 4                                 0.008414
# ..                                     ...
# 995                               0.004478
# 996                               0.006154
# 997                               0.005629
# 998                               0.008404
# 999                               0.003413
#
#      feature_funding_rate_vol_weight__low  \
# 0                               -0.005942
# 1                               -0.001618
# 2                               -0.000404
# 3                               -0.006887
# 4                                0.000008
# ..                                    ...
# 995                             -0.004511
# 996                              0.001963
# 997                             -0.000284
# 998                              0.002763
# 999                              0.003413
#
#      feature_funding_rate_vol_weight__close  \
# 0                                  0.001335
# 1                                  0.006673
# 2                                 -0.000404
# 3                                  0.002456
# 4                                  0.002533
# ..                                      ...
# 995                                0.003279
# 996                                0.001963
# 997                                0.003641
# 998                                0.003413
# 999                                0.003413
#
#      feature_global_long_short_account_ratio__global_account_long_percent  \
# 0                                                                   59.55
# 1                                                                   58.29
# 2                                                                   48.32
# 3                                                                   51.24
# 4                                                                   52.30
# ..                                                                    ...
# 995                                                                 46.68
# 996                                                                 53.32
# 997                                                                 56.43
# 998                                                                 57.65
# 999                                                                 66.47
#
#      feature_global_long_short_account_ratio__global_account_short_percent  \
# 0                                                                    40.45
# 1                                                                    41.71
# 2                                                                    51.68
# 3                                                                    48.76
# 4                                                                    47.70
# ..                                                                     ...
# 995                                                                  53.32
# 996                                                                  46.68
# 997                                                                  43.57
# 998                                                                  42.35
# 999                                                                  33.53
#
#      feature_global_long_short_account_ratio__global_account_long_short_ratio  \
# 0                                                                        1.47
# 1                                                                        1.40
# 2                                                                        0.94
# 3                                                                        1.05
# 4                                                                        1.10
# ..                                                                        ...
# 995                                                                      0.88
# 996                                                                      1.14
# 997                                                                      1.30
# 998                                                                      1.36
# 999                                                                      1.98
#
#      feature_top_long_short_account_ratio__top_account_long_percent  \
# 0                                                             56.20
# 1                                                             56.59
# 2                                                             47.42
# 3                                                             51.41
# 4                                                             52.24
# ..                                                              ...
# 995                                                           50.45
# 996                                                           57.11
# 997                                                           59.43
# 998                                                           60.62
# 999                                                           68.73
#
#      feature_top_long_short_account_ratio__top_account_short_percent  \
# 0                                                              43.80
# 1                                                              43.41
# 2                                                              52.58
# 3                                                              48.59
# 4                                                              47.76
# ..                                                               ...
# 995                                                            49.55
# 996                                                            42.89
# 997                                                            40.57
# 998                                                            39.38
# 999                                                            31.27
#
#      feature_top_long_short_account_ratio__top_account_long_short_ratio  \
# 0                                                                  1.28
# 1                                                                  1.30
# 2                                                                  0.90
# 3                                                                  1.06
# 4                                                                  1.09
# ..                                                                  ...
# 995                                                                1.02
# 996                                                                1.33
# 997                                                                1.47
# 998                                                                1.54
# 999                                                                2.20
#
#      feature_top_long_short_position_ratio__top_position_long_percent  \
# 0                                                               52.89
# 1                                                               54.35
# 2                                                               55.33
# 3                                                               55.68
# 4                                                               55.50
# ..                                                                ...
# 995                                                             62.74
# 996                                                             66.62
# 997                                                             66.23
# 998                                                             67.15
# 999                                                             68.23
#
#      feature_top_long_short_position_ratio__top_position_short_percent  \
# 0                                                                47.11
# 1                                                                45.65
# 2                                                                44.67
# 3                                                                44.32
# 4                                                                44.50
# ..                                                                 ...
# 995                                                              37.26
# 996                                                              33.38
# 997                                                              33.77
# 998                                                              32.85
# 999                                                              31.77
#
#      feature_top_long_short_position_ratio__top_position_long_short_ratio  \
# 0                                                                    1.12
# 1                                                                    1.19
# 2                                                                    1.24
# 3                                                                    1.26
# 4                                                                    1.25
# ..                                                                    ...
# 995                                                                  1.68
# 996                                                                  2.00
# 997                                                                  1.96
# 998                                                                  2.04
# 999                                                                  2.15
#
#      feature_net_position__net_long_change  \
# 0                               -5335.8075
# 1                               12604.1720
# 2                               -1022.6060
# 3                               -2111.2200
# 4                               -1208.4860
# ..                                     ...
# 995                              1598.3650
# 996                             -3606.1295
# 997                               108.8350
# 998                              -926.4995
# 999                              -267.4790
#
#      feature_net_position__net_short_change  \
# 0                               -13333.6725
# 1                                  592.0680
# 2                                 3564.0060
# 3                                 1960.1600
# 4                                -2476.4740
# ..                                      ...
# 995                              -1148.0250
# 996                                932.6695
# 997                               1290.0250
# 998                                555.5795
# 999                               -393.7950
#
#      feature_liquidation_history__long_liquidation_usd  \
# 0                                         1.023348e+07
# 1                                         4.525949e+06
# 2                                         1.601921e+06
# 3                                         4.869615e+05
# 4                                         2.207764e+06
# ..                                                 ...
# 995                                       5.676166e+06
# 996                                       2.941486e+06
# 997                                       8.299577e+05
# 998                                       6.942629e+06
# 999                                       8.134048e+06
#
#      feature_liquidation_history__short_liquidation_usd  \
# 0                                          9.935710e+06
# 1                                          7.722711e+06
# 2                                          2.268934e+06
# 3                                          7.861270e+05
# 4                                          5.157198e+06
# ..                                                  ...
# 995                                        4.301004e+06
# 996                                        1.762504e+06
# 997                                        9.511745e+05
# 998                                        9.089290e+05
# 999                                        2.103941e+06
#
#      feature_liquidation_aggregated__aggregated_long_liquidation_usd  \
# 0                                                       1.689864e+07
# 1                                                       7.505263e+06
# 2                                                       2.821820e+06
# 3                                                       6.733166e+05
# 4                                                       2.881913e+06
# ..                                                               ...
# 995                                                     7.087470e+06
# 996                                                     3.380796e+06
# 997                                                     8.898883e+05
# 998                                                     8.002196e+06
# 999                                                     1.107612e+07
#
#      feature_liquidation_aggregated__aggregated_short_liquidation_usd  \
# 0                                                        1.513053e+07
# 1                                                        9.425951e+06
# 2                                                        2.559745e+06
# 3                                                        8.293305e+05
# 4                                                        6.052503e+06
# ..                                                                ...
# 995                                                      4.623421e+06
# 996                                                      1.874804e+06
# 997                                                      1.008533e+06
# 998                                                      1.085174e+06
# 999                                                      2.512379e+06
#
#      feature_orderbook_ask_bids__bids_usd  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 995                          1.353054e+08
# 996                          1.784007e+08
# 997                          1.276909e+08
# 998                          2.543666e+08
# 999                          1.980043e+08
#
#      feature_orderbook_ask_bids__bids_quantity  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 995                                   1402.029
# 996                                   1875.911
# 997                                   1342.669
# 998                                   2688.808
# 999                                   2136.931
#
#      feature_orderbook_ask_bids__asks_usd  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 995                          9.393401e+07
# 996                          1.296571e+08
# 997                          1.883437e+08
# 998                          1.764464e+08
# 999                          2.122319e+08
#
#      feature_orderbook_ask_bids__asks_quantity  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 995                                    965.810
# 996                                   1351.176
# 997                                   1964.155
# 998                                   1846.565
# 999                                   2268.982
#
#      feature_orderbook_aggregated__aggregated_bids_usd  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                       1.353054e+08
# 996                                       1.784007e+08
# 997                                       1.276909e+08
# 998                                       2.543666e+08
# 999                                       1.979062e+08
#
#      feature_orderbook_aggregated__aggregated_bids_quantity  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ..                                                      ...
# 995                                                1402.029
# 996                                                1875.911
# 997                                                1342.669
# 998                                                2688.808
# 999                                                2135.876
#
#      feature_orderbook_aggregated__aggregated_asks_usd  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                       9.393401e+07
# 996                                       1.296571e+08
# 997                                       1.883437e+08
# 998                                       1.764464e+08
# 999                                       2.120848e+08
#
#      feature_orderbook_aggregated__aggregated_asks_quantity  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ..                                                      ...
# 995                                                 965.810
# 996                                                1351.176
# 997                                                1964.155
# 998                                                1846.565
# 999                                                2267.404
#
#      feature_taker_buy_sell_volume__taker_buy_volume_usd  \
# 0                                           1.860506e+10
# 1                                           1.406976e+10
# 2                                           7.373792e+09
# 3                                           3.131354e+09
# 4                                           6.173944e+09
# ..                                                   ...
# 995                                         7.310207e+09
# 996                                         4.600541e+09
# 997                                         1.799159e+09
# 998                                         2.897470e+09
# 999                                         4.395513e+09
#
#      feature_taker_buy_sell_volume__taker_sell_volume_usd  \
# 0                                            1.836832e+10
# 1                                            1.371284e+10
# 2                                            7.505485e+09
# 3                                            3.249870e+09
# 4                                            6.134385e+09
# ..                                                    ...
# 995                                          7.044570e+09
# 996                                          5.031243e+09
# 997                                          1.911601e+09
# 998                                          3.035915e+09
# 999                                          4.383858e+09
#
#      feature_taker_buy_sell_volume_aggregated__aggregated_buy_volume_usd  \
# 0                                                           2.287095e+10
# 1                                                           1.757678e+10
# 2                                                           9.099976e+09
# 3                                                           3.798899e+09
# 4                                                           7.584599e+09
# ..                                                                   ...
# 995                                                         9.429214e+09
# 996                                                         5.880402e+09
# 997                                                         2.291735e+09
# 998                                                         3.624064e+09
# 999                                                         5.821921e+09
#
#      feature_taker_buy_sell_volume_aggregated__aggregated_sell_volume_usd  \
# 0                                                            2.265738e+10
# 1                                                            1.717978e+10
# 2                                                            9.235610e+09
# 3                                                            3.919416e+09
# 4                                                            7.543390e+09
# ..                                                                    ...
# 995                                                          9.118295e+09
# 996                                                          6.402439e+09
# 997                                                          2.457957e+09
# 998                                                          3.810049e+09
# 999                                                          5.723062e+09
#
#      feature_spot_price_history__open  feature_spot_price_history__high  \
# 0                            28300.80                          30036.00
# 1                            28415.29                          29890.00
# 2                            29472.77                          29599.54
# 3                            29311.69                          29448.88
# 4                            29230.45                          29969.39
# ..                                ...                               ...
# 995                          96951.78                          97193.34
# 996                          95604.81                          95871.47
# 997                          95550.94                          95639.45
# 998                          95147.77                          95531.12
# 999                          93673.14                          93673.14
#
#      feature_spot_price_history__low  feature_spot_price_history__close  \
# 0                           27235.00                           28415.29
# 1                           28378.86                           29472.77
# 2                           28891.00                           29311.70
# 3                           29031.00                           29230.45
# 4                           29079.59                           29233.21
# ..                               ...                                ...
# 995                         95134.48                           95604.80
# 996                         94293.46                           95550.94
# 997                         95021.67                           95147.77
# 998                         93615.40                           93673.14
# 999                         91910.20                           93128.85
#
#      feature_spot_price_history__volume_usd  \
# 0                              3.719701e+09
# 1                              2.784860e+09
# 2                              1.590684e+09
# 3                              5.994669e+08
# 4                              1.172155e+09
# ..                                      ...
# 995                            2.093008e+09
# 996                            1.064019e+09
# 997                            4.081619e+08
# 998                            6.547737e+08
# 999                            1.176724e+09
#
#      feature_bitcoin_lth_supply__price  \
# 0                         28384.234033
# 1                         29465.551427
# 2                         29350.811887
# 3                         29221.514508
# 4                         29362.086797
# ..                                 ...
# 995                       95585.000000
# 996                       95516.000000
# 997                       95100.000000
# 998                       93753.000000
# 999                                NaN
#
#      feature_bitcoin_lth_supply__lth_supply  \
# 0                              1.541781e+07
# 1                              1.543574e+07
# 2                              1.543760e+07
# 3                              1.543902e+07
# 4                              1.544376e+07
# ..                                      ...
# 995                            1.409609e+07
# 996                            1.412253e+07
# 997                            1.414097e+07
# 998                            1.414158e+07
# 999                                     NaN
#
#      feature_bitcoin_lth_supply__supply_pct30  \
# 0                                    0.023558
# 1                                    0.024827
# 2                                    0.024735
# 3                                    0.036017
# 4                                    0.036620
# ..                                        ...
# 995                                  0.005179
# 996                                  0.007060
# 997                                  0.007259
# 998                                  0.006081
# 999                                       NaN
#
#      feature_bitcoin_lth_supply__supply_z180  \
# 0                                   2.129175
# 1                                   2.269670
# 2                                   2.268497
# 3                                   2.263414
# 4                                   2.286923
# ..                                       ...
# 995                                -1.396726
# 996                                -1.338588
# 997                                -1.294035
# 998                                -1.278217
# 999                                      NaN
#
#      feature_bitcoin_lth_supply__supply_slope14  \
# 0                                  34027.857143
# 1                                  32021.428571
# 2                                  29740.000000
# 3                                  26960.000000
# 4                                  23905.714286
# ..                                          ...
# 995                                 1489.770476
# 996                                 2853.429168
# 997                                 3263.027330
# 998                                 3299.893078
# 999                                         NaN
#
#      feature_bitcoin_active_addresses__price  \
# 0                               28300.059274
# 1                               28428.464279
# 2                               29481.013535
# 3                               29336.567035
# 4                               29245.515512
# ..                                       ...
# 995                             96931.291383
# 996                             95554.099561
# 997                             95525.156843
# 998                             95101.178945
# 999                                      NaN
#
#      feature_bitcoin_active_addresses__active_address_count  \
# 0                                                  895177.0
# 1                                                  899175.0
# 2                                                  956323.0
# 3                                                  810081.0
# 4                                                  782314.0
# ..                                                      ...
# 995                                                727968.0
# 996                                                692650.0
# 997                                                604794.0
# 998                                                551983.0
# 999                                                     NaN
#
#      feature_bitcoin_active_addresses__aa_pct7  \
# 0                                    -0.099153
# 1                                    -0.059206
# 2                                    -0.077165
# 3                                    -0.122304
# 4                                    -0.069413
# ..                                         ...
# 995                                   0.160745
# 996                                   0.016694
# 997                                   0.001892
# 998                                  -0.001413
# 999                                        NaN
#
#      feature_bitcoin_active_addresses__aa_z180  \
# 0                                    -0.701076
# 1                                    -0.652739
# 2                                     0.050540
# 3                                    -1.755078
# 4                                    -2.062757
# ..                                         ...
# 995                                   0.314819
# 996                                  -0.213695
# 997                                  -1.500666
# 998                                  -2.236083
# 999                                        NaN
#
#      feature_bitcoin_active_addresses__aa_slope14  \
# 0                                   -10851.214286
# 1                                    -8678.857143
# 2                                    -4329.571429
# 3                                   -17314.071429
# 4                                    -3850.214286
# ..                                            ...
# 995                                   9929.500000
# 996                                    218.571429
# 997                                  -2437.714286
# 998                                  -5124.000000
# 999                                           NaN
#
#      feature_bitcoin_sth_supply__price  \
# 0                         28384.234033
# 1                         29465.551427
# 2                         29350.811887
# 3                         29221.514508
# 4                         29362.086797
# ..                                 ...
# 995                       95585.000000
# 996                       95516.000000
# 997                       95100.000000
# 998                       93753.000000
# 999                                NaN
#
#      feature_bitcoin_sth_supply__sth_supply  \
# 0                              3.939307e+06
# 1                              3.922189e+06
# 2                              3.921248e+06
# 3                              3.920680e+06
# 4                              3.916870e+06
# ..                                      ...
# 995                            5.880261e+06
# 996                            5.854234e+06
# 997                            5.836255e+06
# 998                            5.836088e+06
# 999                                     NaN
#
#      feature_bitcoin_sth_supply__supply_pct30  \
# 0                                   -0.076825
# 1                                   -0.081268
# 2                                   -0.081002
# 3                                   -0.115076
# 4                                   -0.116927
# ..                                        ...
# 995                                 -0.009992
# 996                                 -0.014436
# 997                                 -0.014960
# 998                                 -0.012225
# 999                                       NaN
#
#      feature_bitcoin_sth_supply__supply_z180  \
# 0                                  -1.068754
# 1                                  -1.194307
# 2                                  -1.211435
# 3                                  -1.226185
# 4                                  -1.263695
# ..                                       ...
# 995                                 1.411186
# 996                                 1.354913
# 997                                 1.311860
# 998                                 1.296515
# 999                                      NaN
#
#      feature_bitcoin_sth_supply__supply_slope14  \
# 0                                 -33137.857143
# 1                                 -31136.285714
# 2                                 -28852.142857
# 3                                 -26081.571429
# 4                                 -23016.000000
# ..                                          ...
# 995                                -1054.279405
# 996                                -2421.063097
# 997                                -2832.000544
# 998                                -2869.982364
# 999                                         NaN
#
#      feature_bitcoin_reserve_risk__price  \
# 0                           28384.234033
# 1                           29465.551427
# 2                           29350.811887
# 3                           29221.514508
# 4                           29362.086797
# ..                                   ...
# ...
# 4                                                -0.000128
# ..                                                     ...
# 995                                               0.000657
# 996                                              -0.000065
# 997                                              -0.000163
# 998                                               0.000159
# 999                                              -0.000202
#
#      feature_bitfinex_margin_long_short__long_share__pct1  \
# 0                                                     NaN
# 1                                               -0.001012
# 2                                                0.000248
# 3                                               -0.001334
# 4                                               -0.000129
# ..                                                    ...
# 995                                              0.000659
# 996                                             -0.000065
# 997                                             -0.000164
# 998                                              0.000159
# 999                                             -0.000202
#
#      feature_bitfinex_margin_long_short__log_long_short__diff1  \
# 0                                                          NaN
# 1                                                    -0.108140
# 2                                                     0.025409
# 3                                                    -0.129827
# 4                                                    -0.011703
# ..                                                         ...
# 995                                                   0.241300
# 996                                                  -0.026775
# 997                                                  -0.063990
# 998                                                   0.062167
# 999                                                  -0.078373
#
#      feature_bitfinex_margin_long_short__log_long_short__pct1  \
# 0                                                         NaN
# 1                                                   -0.022932
# 2                                                    0.005515
# 3                                                   -0.028023
# 4                                                   -0.002599
# ..                                                        ...
# 995                                                  0.041727
# 996                                                 -0.004445
# 997                                                 -0.010670
# 998                                                  0.010477
# 999                                                 -0.013072
#
#      feature_coinbase_premium_index__premium__diff1  \
# 0                                               NaN
# 1                                              9.95
# 2                                              0.63
# 3                                             13.58
# 4                                             -8.99
# ..                                              ...
# 995                                           30.63
# 996                                          -28.84
# 997                                          -20.33
# 998                                            9.16
# 999                                           -5.36
#
#      feature_coinbase_premium_index__premium__pct1  \
# 0                                              NaN
# 1                                         2.748619
# 2                                         0.046426
# 3                                         0.956338
# 4                                        -0.323614
# ..                                             ...
# 995                                      -1.078521
# 996                                     -12.932735
# 997                                       0.763998
# 998                                      -0.195143
# 999                                       0.141874
#
#      feature_coinbase_premium_index__premium_rate__diff1  \
# 0                                                    NaN
# 1                                                 0.0350
# 2                                                 0.0004
# 3                                                 0.0466
# 4                                                -0.0305
# ..                                                   ...
# 995                                               0.0321
# 996                                              -0.0301
# 997                                              -0.0213
# 998                                               0.0094
# 999                                              -0.0064
#
#      feature_coinbase_premium_index__premium_rate__pct1  \
# 0                                                   NaN
# 1                                              2.734375
# 2                                              0.008368
# 3                                              0.966805
# 4                                             -0.321730
# ..                                                  ...
# 995                                           -1.077181
# 996                                          -13.086957
# 997                                            0.766187
# 998                                           -0.191446
# 999                                            0.161209
#
#      feature_coinbase_premium_index__premium_abs__diff1  \
# 0                                                   NaN
# 1                                                  9.95
# 2                                                  0.63
# 3                                                 13.58
# 4                                                 -8.99
# ..                                                  ...
# 995                                              -26.17
# 996                                               24.38
# 997                                               20.33
# 998                                               -9.16
# 999                                                5.36
#
#      feature_coinbase_premium_index__premium_abs__pct1  \
# 0                                                  NaN
# 1                                             2.748619
# 2                                             0.046426
# 3                                             0.956338
# 4                                            -0.323614
# ..                                                 ...
# 995                                          -0.921479
# 996                                          10.932735
# 997                                           0.763998
# 998                                          -0.195143
# 999                                           0.141874
#
#      feature_coinbase_premium_index__premium_softsign__diff1  \
# 0                                                        NaN
# 1                                                   0.147816
# 2                                                   0.002845
# 3                                                   0.031043
# 4                                                  -0.015784
# ..                                                       ...
# 995                                                 1.656389
# 996                                                -1.654184
# 997                                                -0.015359
# 998                                                 0.004927
# 999                                                -0.003131
#
#      feature_coinbase_premium_index__premium_softsign__pct1  \
# 0                                                       NaN
# 1                                                  0.188649
# 2                                                  0.003054
# 3                                                  0.033229
# 4                                                 -0.016352
# ..                                                      ...
# 995                                               -1.714712
# 996                                               -2.395970
# 997                                                0.015937
# 998                                               -0.005032
# 999                                                0.003214
#
#      feature_coinbase_premium_index__premium_rate_bps__diff1  \
# 0                                                        NaN
# 1                                                      350.0
# 2                                                        4.0
# 3                                                      466.0
# 4                                                     -305.0
# ..                                                       ...
# 995                                                    321.0
# 996                                                   -301.0
# 997                                                   -213.0
# 998                                                     94.0
# 999                                                    -64.0
#
#      feature_coinbase_premium_index__premium_rate_bps__pct1  \
# 0                                                       NaN
# 1                                                  2.734375
# 2                                                  0.008368
# 3                                                  0.966805
# 4                                                 -0.321730
# ..                                                      ...
# 995                                               -1.077181
# 996                                              -13.086957
# 997                                                0.766187
# 998                                               -0.191446
# 999                                                0.161209
#
#      feature_coinbase_premium_index__implied_ref_price__diff1  \
# 0                                                         NaN
# 1                                                  107.872954
# 2                                                 1071.459557
# 3                                                 -156.783142
# 4                                                  -81.402590
# ..                                                        ...
# 995                                               1654.462963
# 996                                              -1237.051681
# 997                                               -118.611293
# 998                                               -437.086254
# 999                                              -1584.552622
#
#      feature_coinbase_premium_index__implied_ref_price__pct1  \
# 0                                                        NaN
# 1                                                   0.003814
# 2                                                   0.037742
# 3                                                  -0.005322
# 4                                                  -0.002778
# ..                                                       ...
# 995                                                 0.017360
# 996                                                -0.012759
# 997                                                -0.001239
# 998                                                -0.004572
# 999                                                -0.016651
#
#      feature_cgdi_index__index_value__diff1  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 995                                  6.2369
# 996                                -90.9226
# 997                                -12.8978
# 998                                 12.1052
# 999                                -84.1529
#
#      feature_cgdi_index__index_value__pct1  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 995                               0.002763
# 996                              -0.040175
# 997                              -0.005937
# 998                               0.005606
# 999                              -0.038754
#
#      feature_cgdi_index__log_level__diff1  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 995                              0.002760
# 996                             -0.041004
# 997                             -0.005955
# 998                              0.005590
# 999                             -0.039525
#
#      feature_cgdi_index__log_level__pct1  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 995                             0.000357
# 996                            -0.005308
# 997                            -0.000775
# 998                             0.000728
# 999                            -0.005144
#
#      feature_cgdi_index__dev_from_base__diff1  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 995                                    6.2369
# 996                                  -90.9226
# 997                                  -12.8978
# 998                                   12.1052
# 999                                  -84.1529
#
#      feature_cgdi_index__dev_from_base__pct1  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 995                                 0.004962
# 996                                -0.071979
# 997                                -0.011002
# 998                                 0.010441
# 999                                -0.071835
#
#      feature_cgdi_index__dev_softsign__diff1  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 995                                 0.001221
# 996                                -0.018494
# 997                                -0.002750
# 998                                 0.002582
# 999                                -0.018566
#
#      feature_cgdi_index__dev_softsign__pct1
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 995                                0.002192
# 996                               -0.033135
# 997                               -0.005095
# 998                                0.004808
# 999                               -0.034415
#
# [1000 rows x 296 columns]

# %%
print(df_all.isna().sum().to_string())
# Out:
# feature_open_interest_history__open                                                  0
# feature_open_interest_history__high                                                  0
# feature_open_interest_history__low                                                   0
# feature_open_interest_history__close                                                 0
# date                                                                                 0
# feature_open_interest_aggregated__open                                               0
# feature_open_interest_aggregated__high                                               0
# feature_open_interest_aggregated__low                                                0
# feature_open_interest_aggregated__close                                              0
# feature_open_interest_stablecoin__open                                               0
# feature_open_interest_stablecoin__high                                               0
# feature_open_interest_stablecoin__low                                                0
# feature_open_interest_stablecoin__close                                              0
# feature_open_interest_coin_margin__open                                              0
# feature_open_interest_coin_margin__high                                              0
# feature_open_interest_coin_margin__low                                               0
# feature_open_interest_coin_margin__close                                             0
# feature_funding_rate_history__open                                                   0
# feature_funding_rate_history__high                                                   0
# feature_funding_rate_history__low                                                    0
# feature_funding_rate_history__close                                                  0
# feature_funding_rate_oi_weight__open                                                 0
# feature_funding_rate_oi_weight__high                                                 0
# feature_funding_rate_oi_weight__low                                                  0
# feature_funding_rate_oi_weight__close                                                0
# feature_funding_rate_vol_weight__open                                                0
# feature_funding_rate_vol_weight__high                                                0
# feature_funding_rate_vol_weight__low                                                 0
# feature_funding_rate_vol_weight__close                                               0
# feature_global_long_short_account_ratio__global_account_long_percent                 0
# feature_global_long_short_account_ratio__global_account_short_percent                0
# feature_global_long_short_account_ratio__global_account_long_short_ratio             0
# feature_top_long_short_account_ratio__top_account_long_percent                       0
# feature_top_long_short_account_ratio__top_account_short_percent                      0
# feature_top_long_short_account_ratio__top_account_long_short_ratio                   0
# feature_top_long_short_position_ratio__top_position_long_percent                     0
# feature_top_long_short_position_ratio__top_position_short_percent                    0
# feature_top_long_short_position_ratio__top_position_long_short_ratio                 0
# feature_net_position__net_long_change                                                0
# feature_net_position__net_short_change                                               0
# feature_liquidation_history__long_liquidation_usd                                    0
# feature_liquidation_history__short_liquidation_usd                                   0
# feature_liquidation_aggregated__aggregated_long_liquidation_usd                      0
# feature_liquidation_aggregated__aggregated_short_liquidation_usd                     0
# feature_orderbook_ask_bids__bids_usd                                               365
# feature_orderbook_ask_bids__bids_quantity                                          365
# feature_orderbook_ask_bids__asks_usd                                               365
# feature_orderbook_ask_bids__asks_quantity                                          365
# feature_orderbook_aggregated__aggregated_bids_usd                                  365
# feature_orderbook_aggregated__aggregated_bids_quantity                             365
# feature_orderbook_aggregated__aggregated_asks_usd                                  365
# feature_orderbook_aggregated__aggregated_asks_quantity                             365
# feature_taker_buy_sell_volume__taker_buy_volume_usd                                  0
# feature_taker_buy_sell_volume__taker_sell_volume_usd                                 0
# feature_taker_buy_sell_volume_aggregated__aggregated_buy_volume_usd                  0
# feature_taker_buy_sell_volume_aggregated__aggregated_sell_volume_usd                 0
# feature_spot_price_history__open                                                     0
# feature_spot_price_history__high                                                     0
# feature_spot_price_history__low                                                      0
# feature_spot_price_history__close                                                    0
# feature_spot_price_history__volume_usd                                               0
# feature_bitcoin_lth_supply__price                                                    2
# feature_bitcoin_lth_supply__lth_supply                                               2
# feature_bitcoin_lth_supply__supply_pct30                                             2
# feature_bitcoin_lth_supply__supply_z180                                              2
# feature_bitcoin_lth_supply__supply_slope14                                           2
# feature_bitcoin_active_addresses__price                                              1
# feature_bitcoin_active_addresses__active_address_count                               1
# feature_bitcoin_active_addresses__aa_pct7                                            1
# feature_bitcoin_active_addresses__aa_z180                                            1
# feature_bitcoin_active_addresses__aa_slope14                                         1
# feature_bitcoin_sth_supply__price                                                    2
# feature_bitcoin_sth_supply__sth_supply                                               2
# feature_bitcoin_sth_supply__supply_pct30                                             2
# feature_bitcoin_sth_supply__supply_z180                                              2
# feature_bitcoin_sth_supply__supply_slope14                                           2
# feature_bitcoin_reserve_risk__price                                                  2
# feature_bitcoin_reserve_risk__reserve_risk_index                                     2
# feature_bitcoin_reserve_risk__movcd                                                  2
# feature_bitcoin_reserve_risk__hodl_bank                                              2
# feature_bitcoin_reserve_risk__vocd                                                   2
# feature_bitcoin_reserve_risk__log_rr                                                 2
# feature_bitcoin_reserve_risk__rr_z180                                                2
# feature_bitcoin_reserve_risk__rr_slope14                                             2
# feature_bitfinex_margin_long_short__long_quantity                                    0
# feature_bitfinex_margin_long_short__short_quantity                                   0
# feature_bitfinex_margin_long_short__total_qty                                        0
# feature_bitfinex_margin_long_short__long_share                                       0
# feature_bitfinex_margin_long_short__log_long_short                                   0
# feature_coinbase_premium_index__premium                                              0
# feature_coinbase_premium_index__premium_rate                                         0
# feature_coinbase_premium_index__premium_abs                                          0
# feature_coinbase_premium_index__premium_softsign                                     0
# feature_coinbase_premium_index__premium_rate_bps                                     0
# feature_coinbase_premium_index__implied_ref_price                                    0
# feature_cgdi_index__index_value                                                    250
# feature_cgdi_index__log_level                                                      250
# feature_cgdi_index__dev_from_base                                                  250
# feature_cgdi_index__dev_softsign                                                   250
# y_up_1d                                                                              0
# feature_open_interest_history__open__diff1                                           1
# feature_open_interest_history__open__pct1                                            1
# feature_open_interest_history__high__diff1                                           1
# feature_open_interest_history__high__pct1                                            1
# feature_open_interest_history__low__diff1                                            1
# feature_open_interest_history__low__pct1                                             1
# feature_open_interest_history__close__diff1                                          1
# feature_open_interest_history__close__pct1                                           1
# feature_open_interest_aggregated__open__diff1                                        1
# feature_open_interest_aggregated__open__pct1                                         1
# feature_open_interest_aggregated__high__diff1                                        1
# feature_open_interest_aggregated__high__pct1                                         1
# feature_open_interest_aggregated__low__diff1                                         1
# feature_open_interest_aggregated__low__pct1                                          1
# feature_open_interest_aggregated__close__diff1                                       1
# feature_open_interest_aggregated__close__pct1                                        1
# feature_open_interest_stablecoin__open__diff1                                        1
# feature_open_interest_stablecoin__open__pct1                                         1
# feature_open_interest_stablecoin__high__diff1                                        1
# feature_open_interest_stablecoin__high__pct1                                         1
# feature_open_interest_stablecoin__low__diff1                                         1
# feature_open_interest_stablecoin__low__pct1                                          1
# feature_open_interest_stablecoin__close__diff1                                       1
# feature_open_interest_stablecoin__close__pct1                                        1
# feature_open_interest_coin_margin__open__diff1                                       1
# feature_open_interest_coin_margin__open__pct1                                        1
# feature_open_interest_coin_margin__high__diff1                                       1
# feature_open_interest_coin_margin__high__pct1                                        1
# feature_open_interest_coin_margin__low__diff1                                        1
# feature_open_interest_coin_margin__low__pct1                                         1
# feature_open_interest_coin_margin__close__diff1                                      1
# feature_open_interest_coin_margin__close__pct1                                       1
# feature_funding_rate_history__open__diff1                                            1
# feature_funding_rate_history__open__pct1                                             1
# feature_funding_rate_history__high__diff1                                            1
# feature_funding_rate_history__high__pct1                                             1
# feature_funding_rate_history__low__diff1                                             1
# feature_funding_rate_history__low__pct1                                              1
# feature_funding_rate_history__close__diff1                                           1
# feature_funding_rate_history__close__pct1                                            1
# feature_funding_rate_oi_weight__open__diff1                                          1
# feature_funding_rate_oi_weight__open__pct1                                           1
# feature_funding_rate_oi_weight__high__diff1                                          1
# feature_funding_rate_oi_weight__high__pct1                                           1
# feature_funding_rate_oi_weight__low__diff1                                           1
# feature_funding_rate_oi_weight__low__pct1                                            1
# feature_funding_rate_oi_weight__close__diff1                                         1
# feature_funding_rate_oi_weight__close__pct1                                          1
# feature_funding_rate_vol_weight__open__diff1                                         1
# feature_funding_rate_vol_weight__open__pct1                                          1
# feature_funding_rate_vol_weight__high__diff1                                         1
# feature_funding_rate_vol_weight__high__pct1                                          1
# feature_funding_rate_vol_weight__low__diff1                                          1
# feature_funding_rate_vol_weight__low__pct1                                           1
# feature_funding_rate_vol_weight__close__diff1                                        1
# feature_funding_rate_vol_weight__close__pct1                                         1
# feature_global_long_short_account_ratio__global_account_long_percent__diff1          1
# feature_global_long_short_account_ratio__global_account_long_percent__pct1           1
# feature_global_long_short_account_ratio__global_account_short_percent__diff1         1
# feature_global_long_short_account_ratio__global_account_short_percent__pct1          1
# feature_global_long_short_account_ratio__global_account_long_short_ratio__diff1      1
# feature_global_long_short_account_ratio__global_account_long_short_ratio__pct1       1
# feature_top_long_short_account_ratio__top_account_long_percent__diff1                1
# feature_top_long_short_account_ratio__top_account_long_percent__pct1                 1
# feature_top_long_short_account_ratio__top_account_short_percent__diff1               1
# feature_top_long_short_account_ratio__top_account_short_percent__pct1                1
# feature_top_long_short_account_ratio__top_account_long_short_ratio__diff1            1
# feature_top_long_short_account_ratio__top_account_long_short_ratio__pct1             1
# feature_top_long_short_position_ratio__top_position_long_percent__diff1              1
# feature_top_long_short_position_ratio__top_position_long_percent__pct1               1
# feature_top_long_short_position_ratio__top_position_short_percent__diff1             1
# feature_top_long_short_position_ratio__top_position_short_percent__pct1              1
# feature_top_long_short_position_ratio__top_position_long_short_ratio__diff1          1
# feature_top_long_short_position_ratio__top_position_long_short_ratio__pct1           1
# feature_net_position__net_long_change__diff1                                         1
# feature_net_position__net_long_change__pct1                                          1
# feature_net_position__net_short_change__diff1                                        1
# feature_net_position__net_short_change__pct1                                         1
# feature_liquidation_history__long_liquidation_usd__diff1                             1
# feature_liquidation_history__long_liquidation_usd__pct1                              1
# feature_liquidation_history__short_liquidation_usd__diff1                            1
# feature_liquidation_history__short_liquidation_usd__pct1                             1
# feature_liquidation_aggregated__aggregated_long_liquidation_usd__diff1               1
# feature_liquidation_aggregated__aggregated_long_liquidation_usd__pct1                1
# feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1              1
# feature_liquidation_aggregated__aggregated_short_liquidation_usd__pct1               1
# feature_orderbook_ask_bids__bids_usd__diff1                                        366
# feature_orderbook_ask_bids__bids_usd__pct1                                         366
# feature_orderbook_ask_bids__bids_quantity__diff1                                   366
# feature_orderbook_ask_bids__bids_quantity__pct1                                    366
# feature_orderbook_ask_bids__asks_usd__diff1                                        366
# feature_orderbook_ask_bids__asks_usd__pct1                                         366
# feature_orderbook_ask_bids__asks_quantity__diff1                                   366
# feature_orderbook_ask_bids__asks_quantity__pct1                                    366
# feature_orderbook_aggregated__aggregated_bids_usd__diff1                           366
# feature_orderbook_aggregated__aggregated_bids_usd__pct1                            366
# feature_orderbook_aggregated__aggregated_bids_quantity__diff1                      366
# feature_orderbook_aggregated__aggregated_bids_quantity__pct1                       366
# feature_orderbook_aggregated__aggregated_asks_usd__diff1                           366
# feature_orderbook_aggregated__aggregated_asks_usd__pct1                            366
# feature_orderbook_aggregated__aggregated_asks_quantity__diff1                      366
# feature_orderbook_aggregated__aggregated_asks_quantity__pct1                       366
# feature_taker_buy_sell_volume__taker_buy_volume_usd__diff1                           1
# feature_taker_buy_sell_volume__taker_buy_volume_usd__pct1                            1
# feature_taker_buy_sell_volume__taker_sell_volume_usd__diff1                          1
# feature_taker_buy_sell_volume__taker_sell_volume_usd__pct1                           1
# feature_taker_buy_sell_volume_aggregated__aggregated_buy_volume_usd__diff1           1
# feature_taker_buy_sell_volume_aggregated__aggregated_buy_volume_usd__pct1            1
# feature_taker_buy_sell_volume_aggregated__aggregated_sell_volume_usd__diff1          1
# feature_taker_buy_sell_volume_aggregated__aggregated_sell_volume_usd__pct1           1
# feature_spot_price_history__open__diff1                                              1
# feature_spot_price_history__open__pct1                                               1
# feature_spot_price_history__high__diff1                                              1
# feature_spot_price_history__high__pct1                                               1
# feature_spot_price_history__low__diff1                                               1
# feature_spot_price_history__low__pct1                                                1
# feature_spot_price_history__close__diff1                                             1
# feature_spot_price_history__close__pct1                                              1
# feature_spot_price_history__volume_usd__diff1                                        1
# feature_spot_price_history__volume_usd__pct1                                         1
# feature_bitcoin_lth_supply__price__diff1                                             4
# feature_bitcoin_lth_supply__price__pct1                                              1
# feature_bitcoin_lth_supply__lth_supply__diff1                                        4
# feature_bitcoin_lth_supply__lth_supply__pct1                                         1
# feature_bitcoin_lth_supply__supply_pct30__diff1                                      4
# feature_bitcoin_lth_supply__supply_pct30__pct1                                       1
# feature_bitcoin_lth_supply__supply_z180__diff1                                       4
# feature_bitcoin_lth_supply__supply_z180__pct1                                        1
# feature_bitcoin_lth_supply__supply_slope14__diff1                                    4
# feature_bitcoin_lth_supply__supply_slope14__pct1                                     1
# feature_bitcoin_active_addresses__price__diff1                                       2
# feature_bitcoin_active_addresses__price__pct1                                        1
# feature_bitcoin_active_addresses__active_address_count__diff1                        2
# feature_bitcoin_active_addresses__active_address_count__pct1                         1
# feature_bitcoin_active_addresses__aa_pct7__diff1                                     2
# feature_bitcoin_active_addresses__aa_pct7__pct1                                      1
# feature_bitcoin_active_addresses__aa_z180__diff1                                     2
# feature_bitcoin_active_addresses__aa_z180__pct1                                      1
# feature_bitcoin_active_addresses__aa_slope14__diff1                                  2
# feature_bitcoin_active_addresses__aa_slope14__pct1                                   1
# feature_bitcoin_sth_supply__price__diff1                                             4
# feature_bitcoin_sth_supply__price__pct1                                              1
# feature_bitcoin_sth_supply__sth_supply__diff1                                        4
# feature_bitcoin_sth_supply__sth_supply__pct1                                         1
# feature_bitcoin_sth_supply__supply_pct30__diff1                                      4
# feature_bitcoin_sth_supply__supply_pct30__pct1                                       1
# feature_bitcoin_sth_supply__supply_z180__diff1                                       4
# feature_bitcoin_sth_supply__supply_z180__pct1                                        1
# feature_bitcoin_sth_supply__supply_slope14__diff1                                    4
# feature_bitcoin_sth_supply__supply_slope14__pct1                                     1
# feature_bitcoin_reserve_risk__price__diff1                                           4
# feature_bitcoin_reserve_risk__price__pct1                                            1
# feature_bitcoin_reserve_risk__reserve_risk_index__diff1                              4
# feature_bitcoin_reserve_risk__reserve_risk_index__pct1                               1
# feature_bitcoin_reserve_risk__movcd__diff1                                           4
# feature_bitcoin_reserve_risk__movcd__pct1                                            1
# feature_bitcoin_reserve_risk__hodl_bank__diff1                                       4
# feature_bitcoin_reserve_risk__hodl_bank__pct1                                        1
# feature_bitcoin_reserve_risk__vocd__diff1                                            4
# feature_bitcoin_reserve_risk__vocd__pct1                                             1
# feature_bitcoin_reserve_risk__log_rr__diff1                                          4
# feature_bitcoin_reserve_risk__log_rr__pct1                                           1
# feature_bitcoin_reserve_risk__rr_z180__diff1                                         4
# feature_bitcoin_reserve_risk__rr_z180__pct1                                          1
# feature_bitcoin_reserve_risk__rr_slope14__diff1                                      4
# feature_bitcoin_reserve_risk__rr_slope14__pct1                                       1
# feature_bitfinex_margin_long_short__long_quantity__diff1                             1
# feature_bitfinex_margin_long_short__long_quantity__pct1                              1
# feature_bitfinex_margin_long_short__short_quantity__diff1                            1
# feature_bitfinex_margin_long_short__short_quantity__pct1                             1
# feature_bitfinex_margin_long_short__total_qty__diff1                                 1
# feature_bitfinex_margin_long_short__total_qty__pct1                                  1
# feature_bitfinex_margin_long_short__long_share__diff1                                1
# feature_bitfinex_margin_long_short__long_share__pct1                                 1
# feature_bitfinex_margin_long_short__log_long_short__diff1                            1
# feature_bitfinex_margin_long_short__log_long_short__pct1                             1
# feature_coinbase_premium_index__premium__diff1                                       1
# feature_coinbase_premium_index__premium__pct1                                        1
# feature_coinbase_premium_index__premium_rate__diff1                                  1
# feature_coinbase_premium_index__premium_rate__pct1                                   2
# feature_coinbase_premium_index__premium_abs__diff1                                   1
# feature_coinbase_premium_index__premium_abs__pct1                                    1
# feature_coinbase_premium_index__premium_softsign__diff1                              1
# feature_coinbase_premium_index__premium_softsign__pct1                               1
# feature_coinbase_premium_index__premium_rate_bps__diff1                              1
# feature_coinbase_premium_index__premium_rate_bps__pct1                               2
# feature_coinbase_premium_index__implied_ref_price__diff1                             1
# feature_coinbase_premium_index__implied_ref_price__pct1                              1
# feature_cgdi_index__index_value__diff1                                             251
# feature_cgdi_index__index_value__pct1                                              251
# feature_cgdi_index__log_level__diff1                                               251
# feature_cgdi_index__log_level__pct1                                                251
# feature_cgdi_index__dev_from_base__diff1                                           251
# feature_cgdi_index__dev_from_base__pct1                                            252
# feature_cgdi_index__dev_softsign__diff1                                            251
# feature_cgdi_index__dev_softsign__pct1                                             252
