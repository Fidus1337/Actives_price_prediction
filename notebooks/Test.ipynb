# %%
from dotenv import load_dotenv
import os
from FeaturesGetterModule.FeaturesGetter import FeaturesGetter
import numpy as np

import warnings
warnings.filterwarnings("ignore")

load_dotenv("dev.env")
API_KEY = os.getenv("COINGLASS_API_KEY")

if not API_KEY:
    raise ValueError("COINGLASS_API_KEY not found in dev.env")

# Создаём экземпляр FeaturesGetter
getter = FeaturesGetter(api_key=API_KEY)

import pandas as pd

# Показывать все колонки
pd.set_option('display.max_columns', None)

# Опционально: не обрезать ширину колонок
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Checking features (and comparing to YurasCode)

# %%
df_oi = getter.get_history(endpoint_name="open_interest_history")
rows, cols = df_oi.shape
print(f"Строк: {rows}, Столбцов: {cols}")
# Out:
# Строк: 1000, Столбцов: 5

# %%
df_oi_agg = getter.get_history(endpoint_name="open_interest_aggregated")
rows, cols = df_oi_agg.shape
print(f"Строк: {rows}, Столбцов: {cols}")
# Out:
# Строк: 1000, Столбцов: 5

# %%
df_oi_stable_coin = getter.get_history(endpoint_name="open_interest_stablecoin")
rows, cols = df_oi_stable_coin.shape
print(f"Строк: {rows}, Столбцов: {cols}")
# Out:
# Строк: 1000, Столбцов: 5

# %%
df_rate_history = getter.get_history(endpoint_name="funding_rate_history")
rows, cols = df_rate_history.shape
print(f"Строк: {rows}, Столбцов: {cols}")

# %%
df_funding_rate_oi_weight = getter.get_history(endpoint_name="funding_rate_oi_weight")
rows, cols = df_funding_rate_oi_weight.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_funding_rate_oi_weight.tail()

# %%
df_funding_rate_vol_weight = getter.get_history(endpoint_name="funding_rate_vol_weight", prefix="feature_" + "funding_rate_vol_weight")
rows, cols = df_funding_rate_vol_weight.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_funding_rate_vol_weight.tail()

# %%
df_global_long_short_account_ratio = getter.get_history(endpoint_name="global_long_short_account_ratio", prefix="feature")
rows, cols = df_global_long_short_account_ratio.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_global_long_short_account_ratio.tail()

# %%
df_top_long_short_account_ratio = getter.get_history(endpoint_name="top_long_short_account_ratio", prefix="feature")
rows, cols = df_top_long_short_account_ratio.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_top_long_short_account_ratio.tail()

# %%
df_top_long_short_position_ratio = getter.get_history(endpoint_name="top_long_short_position_ratio", prefix="feature")
rows, cols = df_top_long_short_position_ratio.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_top_long_short_position_ratio.tail()

# %%
df_net_pos = getter.get_history(endpoint_name="net_position", prefix="feature")
rows, cols = df_net_pos.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_net_pos.tail()

# %%
df_liqidation_history = getter.get_history(endpoint_name="liquidation_history", prefix="feature")
rows, cols = df_liqidation_history.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_liqidation_history.tail()

# %%
df_liqidation_history = getter.get_history(endpoint_name="liquidation_aggregated", prefix="feature")
rows, cols = df_liqidation_history.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_liqidation_history.tail()

# %%
df_orderbook_ask_bids = getter.get_history(endpoint_name="orderbook_ask_bids", prefix="feature")
rows, cols = df_orderbook_ask_bids.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_orderbook_ask_bids.tail()

# %%
df_orderbook_aggregated = getter.get_history(endpoint_name="orderbook_aggregated", prefix="feature")
rows, cols = df_orderbook_aggregated.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_orderbook_aggregated.tail()

# %%
df_taker_buy_sell_volume = getter.get_history(endpoint_name="taker_buy_sell_volume", prefix="feature")
rows, cols = df_taker_buy_sell_volume.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_taker_buy_sell_volume.tail()

# %%
df_bitcoin_lth_supply = getter.get_bitcoin_lth_supply(prefix="feature_" + "bitcoin_lth_supply")
rows, cols = df_bitcoin_lth_supply.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_bitcoin_lth_supply.tail()

# %%
df_get_bitcoin_active_addresses = getter.get_bitcoin_active_addresses(prefix="feature_" + "get_bitcoin_active_addresses")
rows, cols = df_get_bitcoin_active_addresses.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_get_bitcoin_active_addresses.tail()

# %%
df_get_bitcoin_sth_supply = getter.get_bitcoin_sth_supply(prefix="feature_" + "get_bitcoin_sth_supply")
rows, cols = df_get_bitcoin_sth_supply.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_get_bitcoin_sth_supply.tail()

# %%
df_taker_buy_sell_volume_aggregated = getter.get_history(endpoint_name="taker_buy_sell_volume_aggregated", prefix="feature")
rows, cols = df_taker_buy_sell_volume_aggregated.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_taker_buy_sell_volume_aggregated.tail()

# %%
df_get_bitfinex_margin_long_short = getter.get_bitfinex_margin_long_short(prefix="feature_" + "bitfinex_margin_long_short")
rows, cols = df_get_bitfinex_margin_long_short.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_get_bitfinex_margin_long_short.tail()

# %%
df_cgdi_index = getter.get_cgdi_index(prefix="feature_" + "cgdi_index")
rows, cols = df_cgdi_index.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_cgdi_index.tail()

# %%
df_coinbase_premium_index = getter.get_coinbase_premium_index(prefix="feature_" + "coinbase_premium_index")
rows, cols = df_coinbase_premium_index.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_coinbase_premium_index.tail()

# %%
df_get_bitcoin_reserve_risk = getter.get_bitcoin_reserve_risk(prefix="feature_" + "get_bitcoin_reserve_risk")
rows, cols = df_get_bitcoin_reserve_risk.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_get_bitcoin_reserve_risk.tail()

# %%
df_open_interest_coin_margin = getter.get_history(prefix="feature_" + "open_interest_coin_margin", endpoint_name="open_interest_coin_margin")
rows, cols = df_open_interest_coin_margin.shape
print(f"Строк: {rows}, Столбцов: {cols}")

df_open_interest_coin_margin.tail()

# %% [markdown]
# ## Merging features into one dataset by date

# %%
from Getting_and_preprocessing_features import fetch_all_coinglass_features, print_features_summary, merge_all_features

# Загружаем все фичи
print("Загрузка фичей с CoinGlass...")
features = fetch_all_coinglass_features(getter)

# Выводим сводку
print_features_summary(features)

# Объединяем в один DataFrame
print("\nОбъединение фичей...")
df_all = merge_all_features(features)

# Удаляем строки где нет данных по spot price (до ~2019 года)
df_all = df_all.dropna(subset=["spot_price_history__close"]).reset_index(drop=True)
print(f"После dropna: {len(df_all)} записей, {len(df_all.columns)} колонок")

for col in df_all.isna().sum():
    print(col)
# Out:
# Загрузка фичей с CoinGlass...
# ======================================================================
# СВОДКА ПО ЗАГРУЖЕННЫМ ФИЧАМ
# ======================================================================
#   open_interest_history: 1000 записей, 5 колонок, 2023-04-27 — 2026-01-20
#   open_interest_aggregated: 1000 записей, 5 колонок, 2023-04-27 — 2026-01-20
#   open_interest_stablecoin: 1000 записей, 5 колонок, 2023-04-27 — 2026-01-20
#   open_interest_coin_margin: 1000 записей, 5 колонок, 2023-04-27 — 2026-01-20
#   funding_rate_history: 1000 записей, 5 колонок, 2023-04-27 — 2026-01-20
#   funding_rate_oi_weight: 1000 записей, 5 колонок, 2023-04-27 — 2026-01-20
#   funding_rate_vol_weight: 1000 записей, 5 колонок, 2023-04-27 — 2026-01-20
#   global_long_short_account_ratio: 1000 записей, 4 колонок, 2023-04-27 — 2026-01-20
#   top_long_short_account_ratio: 1000 записей, 4 колонок, 2023-04-27 — 2026-01-20
#   top_long_short_position_ratio: 1000 записей, 4 колонок, 2023-04-27 — 2026-01-20
#   net_position: 1000 записей, 3 колонок, 2023-04-27 — 2026-01-20
#   liquidation_history: 1000 записей, 3 колонок, 2023-04-27 — 2026-01-20
#   liquidation_aggregated: 1000 записей, 3 колонок, 2023-04-27 — 2026-01-20
#   orderbook_ask_bids: 636 записей, 5 колонок, 2024-04-25 — 2026-01-20
#   orderbook_aggregated: 636 записей, 5 колонок, 2024-04-25 — 2026-01-20
#   taker_buy_sell_volume: 1000 записей, 3 колонок, 2023-04-27 — 2026-01-20
#   taker_buy_sell_volume_aggregated: 1000 записей, 3 колонок, 2023-04-27 — 2026-01-20
#   spot_price_history: 1000 записей, 6 колонок, 2023-04-27 — 2026-01-20
#   bitcoin_lth_supply: 5268 записей, 6 колонок, 2011-08-18 — 2026-01-19
#   bitcoin_active_addresses: 5635 записей, 6 колонок, 2010-08-17 — 2026-01-19
#   bitcoin_sth_supply: 5268 записей, 6 колонок, 2011-08-18 — 2026-01-19
#   bitcoin_reserve_risk: 5634 записей, 9 колонок, 2010-08-17 — 2026-01-19
#   bitfinex_margin_long_short: 1000 записей, 6 колонок, 2023-04-27 — 2026-01-20
#   coinbase_premium_index: 1000 записей, 7 колонок, 2023-04-27 — 2026-01-20
#   cgdi_index: 751 записей, 5 колонок, 2024-01-01 — 2026-01-20
# ======================================================================
#
# Объединение фичей...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18344\3055252754.py in ?()
#      11 print("\nОбъединение фичей...")
#      12 df_all = merge_all_features(features)
#      13
#      14 # Удаляем строки где нет данных по spot price (до ~2019 года)
# ---> 15 df_all = df_all.dropna(subset=["spot_price_history__close"]).reset_index(drop=True)
#      16 print(f"После dropna: {len(df_all)} записей, {len(df_all.columns)} колонок")
#      17
#      18 for col in df_all.isna().sum():
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6673             ax = self._get_axis(agg_axis)
#    6674             indices = ax.get_indexer_for(subset)
#    6675             check = indices == -1
#    6676             if check.any():
# -> 6677                 raise KeyError(np.array(subset)[check].tolist())
#    6678             agg_obj = self.take(indices, axis=agg_axis)
#    6679
#    6680         if thresh is not lib.no_default:
#
# KeyError: ['spot_price_history__close']

# %% [markdown]
# ## Adding traget column (the price has grown comparing to previous day or not?)

# %%
import pandas as pd

N_DAYS = 1

def add_y_up_1d(df: pd.DataFrame, close_col: str = "spot_price_history__close") -> pd.DataFrame:
    out = df.copy()
    out["date"] = pd.to_datetime(out["date"], errors="coerce")
    out = out.sort_values("date", kind="stable").reset_index(drop=True)

    c = pd.to_numeric(out[close_col], errors="coerce")
    out["y_up_1d"] = (c.shift(-1*N_DAYS) > c).astype("Int64")
    return out

df_all = add_y_up_1d(df_all, close_col="spot_price_history__close")

df_all = df_all.dropna(subset=["y_up_1d", "spot_price_history__close"]).reset_index(drop=True)

# Синтаксис: [все_строки, от_колонки_date : до_конца]
# df_all.loc[:, "date":]

# %% [markdown]
# ## Feature engineering

# %%
import pandas as pd
import numpy as np

def add_engineered_features(df: pd.DataFrame) -> pd.DataFrame:
    # Сначала создаем список для новых колонок
    new_features = []
    
    # Список колонок для обработки
    base_numeric = [
        c for c in df.columns
        if c not in {"date", "y_up_1d"}
        and pd.api.types.is_numeric_dtype(df[c])
    ]
    
    # 1. Генерируем Diff и Pct (собираем их в список, НЕ вставляем в df сразу)
    for c in base_numeric:
        # Diff
        diff_col = df[c].diff(1)
        diff_col.name = c + "__diff1"  # Обязательно даем имя Series
        new_features.append(diff_col)
        
        # Pct
        pct_col = df[c].pct_change(1)
        pct_col.name = c + "__pct1"
        new_features.append(pct_col)
    
    # 2. Склеиваем всё разом (ОДНА операция вместо сотен)
    if new_features:
        # Создаем DataFrame из новых фичей
        df_new = pd.concat(new_features, axis=1)
        # Приклеиваем его к исходному
        out = pd.concat([df, df_new], axis=1)
    else:
        out = df.copy()

    # 3. Imbalances (их всего 4 штуки, тут вставка по одной не страшна)
    eps = 1e-12
    
    def _imbalance(num_col_a, num_col_b, new_col):
        # Проверяем наличие в out (теперь там есть и старые, и новые колонки)
        if num_col_a in out.columns and num_col_b in out.columns:
            a = pd.to_numeric(out[num_col_a], errors="coerce")
            b = pd.to_numeric(out[num_col_b], errors="coerce")
            out[new_col] = (a - b) / (a + b + eps)

    _imbalance(
        "futures_v2_taker_buy_sell_volume_history__taker_buy_volume_usd",
        "futures_v2_taker_buy_sell_volume_history__taker_sell_volume_usd",
        "feat__taker_imbalance_v2",
    )
    _imbalance(
        "futures_aggregated_taker_buy_sell_volume_history__aggregated_buy_volume_usd",
        "futures_aggregated_taker_buy_sell_volume_history__aggregated_sell_volume_usd",
        "feat__taker_imbalance_agg",
    )
    _imbalance(
        "futures_liquidation_history__short_liquidation_usd",
        "futures_liquidation_history__long_liquidation_usd",
        "feat__liq_imbalance_short_minus_long",
    )
    _imbalance(
        "futures_orderbook_ask_bids_history__bids_usd",
        "futures_orderbook_ask_bids_history__asks_usd",
        "feat__orderbook_imbalance_usd",
    )

    # 4. Чистим бесконечности
    out = out.replace([np.inf, -np.inf], np.nan)
    return out

# Вызов функции
df_with_all_features = add_engineered_features(df_all)
df_all = add_engineered_features(df_all)

# Переименовываем колонки spot_price_history для удобства
df_all = df_all.rename(columns={
    "spot_price_history__open": "open",
    "spot_price_history__high": "high",
    "spot_price_history__low": "low",
    "spot_price_history__close": "close",
    "spot_price_history__volume_usd": "volume_usd",
})

df_with_all_features = df_all.copy()

# %% [markdown]
# ## Looking for the most correlated features to target var (Spearman/Pearson)

# %%
# ---------- Benjamini-Hochberg FDR correction ----------
def bh_fdr(pvals: pd.Series) -> pd.Series:
    """Benjamini–Hochberg FDR correction."""
    p = pvals.dropna()
    n = len(p)
    out = pd.Series(np.nan, index=pvals.index, dtype="float64")
    if n == 0:
        return out
    order = np.argsort(p.values)
    ranked = p.values[order]
    q = ranked * n / (np.arange(1, n + 1))
    q = np.minimum.accumulate(q[::-1])[::-1]
    out.loc[p.index[order]] = np.clip(q, 0, 1)
    return out


# ---------- Корреляции + p-value + FDR ----------
def corr_report(df: pd.DataFrame, method: str = "pearson", min_n: int = 60) -> pd.DataFrame:
    tmp = df.copy()
    tmp["y_up_1d"] = pd.to_numeric(tmp["y_up_1d"], errors="coerce")

    features = [
        c for c in tmp.columns
        if c not in {"date", "y_up_1d"}
        and pd.api.types.is_numeric_dtype(tmp[c])
    ]

    # быстрый corr (без p-values)
    corr = tmp[features].corrwith(tmp["y_up_1d"], method=method)
    res = corr.rename("corr").to_frame()
    res["abs_corr"] = res["corr"].abs()

    # n по каждой фиче
    y = tmp["y_up_1d"]
    n_list = []
    for c in features:
        m = tmp[c].notna() & y.notna()
        n_list.append(int(m.sum()))
    res["n"] = n_list

    # p-values если доступен scipy
    try:
        from scipy.stats import pearsonr, spearmanr
        pvals = []
        for c in features:
            m = tmp[c].notna() & y.notna()
            if m.sum() < min_n:
                pvals.append(np.nan)
                continue
            x = pd.to_numeric(tmp.loc[m, c], errors="coerce")
            yy = tmp.loc[m, "y_up_1d"]
            # Дополнительная проверка на NaN после pd.to_numeric
            valid = x.notna() & yy.notna()
            if valid.sum() < min_n:
                pvals.append(np.nan)
                continue
            x_clean, yy_clean = x[valid], yy[valid]
            if method == "pearson":
                _, p = pearsonr(x_clean, yy_clean)
            else:
                _, p = spearmanr(x_clean, yy_clean)
            pvals.append(p)
        res["p_value"] = pvals
        res["q_value_fdr"] = bh_fdr(res["p_value"])
    except Exception as e:
        print(f"Warning: p-value calculation failed: {e}")

    res = (
        res.reset_index()
           .rename(columns={"index": "feature"})
           .sort_values("abs_corr", ascending=False)
           .reset_index(drop=True)
    )
    return res


# ===================== RUN =====================
pear = corr_report(df_all, method="pearson", min_n=60)
spear = corr_report(df_all, method="spearman", min_n=60)

print("Top-30 Pearson correlations:")
display(pear.head(30))

print("\nTop-30 Spearman correlations:")
display(spear.head(30))
# Out:
# Top-30 Pearson correlations:
#                                                                            feature  \
# 0                                      feature_bitcoin_reserve_risk__log_rr__diff1
# 1                                          feature_bitcoin_sth_supply__price__pct1
# 2                                        feature_bitcoin_reserve_risk__price__pct1
# 3                                          feature_bitcoin_lth_supply__price__pct1
# 4                           feature_bitcoin_reserve_risk__reserve_risk_index__pct1
# 5                                       feature_bitcoin_reserve_risk__log_rr__pct1
# 6                                    feature_open_interest_aggregated__close__pct1
# 7          feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1
# 8                                          feature_spot_price_history__close__pct1
# 9                          feature_bitcoin_reserve_risk__reserve_risk_index__diff1
# 10      feature_global_long_short_account_ratio__global_account_long_percent__pct1
# 11                              feature_bitcoin_active_addresses__aa_slope14__pct1
# 12                                        feature_funding_rate_history__open__pct1
# 13                                  feature_bitcoin_sth_supply__supply_pct30__pct1
# 14            feature_top_long_short_account_ratio__top_account_long_percent__pct1
# 15                                     feature_coinbase_premium_index__premium_abs
# 16                                          feature_bitcoin_lth_supply__lth_supply
# 17  feature_global_long_short_account_ratio__global_account_long_short_ratio__pct1
# 18                       feature_liquidation_history__short_liquidation_usd__diff1
# 19     feature_global_long_short_account_ratio__global_account_long_percent__diff1
# 20    feature_global_long_short_account_ratio__global_account_short_percent__diff1
# 21     feature_top_long_short_position_ratio__top_position_long_short_ratio__diff1
# 22        feature_top_long_short_account_ratio__top_account_long_short_ratio__pct1
# 23                                     feature_open_interest_aggregated__low__pct1
# 24          feature_top_long_short_account_ratio__top_account_short_percent__diff1
# 25           feature_top_long_short_account_ratio__top_account_long_percent__diff1
# 26                       feature_bitfinex_margin_long_short__log_long_short__diff1
# 27                                    feature_bitcoin_reserve_risk__rr_z180__diff1
# 28      feature_top_long_short_position_ratio__top_position_long_short_ratio__pct1
# 29         feature_top_long_short_position_ratio__top_position_short_percent__pct1
#
#         corr  abs_corr     n   p_value  q_value_fdr
# 0  -0.068402  0.068402   996  0.030886     0.907785
# 1  -0.067929  0.067929   999  0.031808     0.907785
# 2  -0.067929  0.067929   999  0.031808     0.907785
# 3  -0.067929  0.067929   999  0.031808     0.907785
# 4  -0.067543  0.067543   999  0.032795     0.907785
# 5   0.066819  0.066819   999  0.034715     0.907785
# 6  -0.065815  0.065815   999  0.037539     0.907785
# 7  -0.063726  0.063726   999  0.044040     0.907785
# 8  -0.062526  0.062526   999  0.048188     0.907785
# 9  -0.061507  0.061507   996  0.052317     0.907785
# 10 -0.061475  0.061475   999  0.052083     0.907785
# 11 -0.061129  0.061129   999  0.053421     0.907785
# 12 -0.060186  0.060186   999  0.057218     0.907785
# 13 -0.059003  0.059003   999  0.062296     0.907785
# 14 -0.058596  0.058596   999  0.064123     0.907785
# 15  0.058288  0.058288  1000  0.065402     0.907785
# 16  0.056903  0.056903   998  0.072364     0.907785
# 17 -0.056802  0.056802   999  0.072727     0.907785
# 18 -0.055749  0.055749   999  0.078201     0.907785
# 19 -0.054613  0.054613   999  0.084478     0.907785
# 20  0.054613  0.054613   999  0.084478     0.907785
# 21 -0.054448  0.054448   999  0.085425     0.907785
# 22 -0.054227  0.054227   999  0.086698     0.907785
# 23 -0.053460  0.053460   999  0.091258     0.907785
# 24  0.053032  0.053032   999  0.093883     0.907785
# 25 -0.053032  0.053032   999  0.093883     0.907785
# 26 -0.051494  0.051494   999  0.103822     0.907785
# 27 -0.050576  0.050576   996  0.110676     0.907785
# 28 -0.050325  0.050325   999  0.111919     0.907785
# 29  0.050038  0.050038   999  0.113978     0.907785
# Top-30 Spearman correlations:
#                                                                            feature  \
# 0                                      feature_bitcoin_reserve_risk__rr_z180__pct1
# 1                                    feature_open_interest_aggregated__close__pct1
# 2                                   feature_open_interest_aggregated__close__diff1
# 3                                     feature_bitcoin_reserve_risk__rr_z180__diff1
# 4                                      feature_bitcoin_reserve_risk__log_rr__diff1
# 5                                          feature_bitcoin_sth_supply__price__pct1
# 6                                          feature_bitcoin_lth_supply__price__pct1
# 7                                        feature_bitcoin_reserve_risk__price__pct1
# 8                           feature_bitcoin_reserve_risk__reserve_risk_index__pct1
# 9       feature_global_long_short_account_ratio__global_account_long_percent__pct1
# 10                                      feature_bitcoin_reserve_risk__log_rr__pct1
# 11                         feature_bitcoin_reserve_risk__reserve_risk_index__diff1
# 12  feature_global_long_short_account_ratio__global_account_long_short_ratio__pct1
# 13    feature_global_long_short_account_ratio__global_account_short_percent__diff1
# 14     feature_global_long_short_account_ratio__global_account_long_percent__diff1
# 15                                          feature_bitcoin_lth_supply__lth_supply
# 16                                  feature_bitcoin_sth_supply__supply_pct30__pct1
# 17                                          feature_cgdi_index__dev_softsign__pct1
# 18     feature_global_long_short_account_ratio__global_account_short_percent__pct1
# 19                                         feature_spot_price_history__close__pct1
# 20                                        feature_bitcoin_lth_supply__price__diff1
# 21                                        feature_bitcoin_sth_supply__price__diff1
# 22                                      feature_bitcoin_reserve_risk__price__diff1
# 23            feature_top_long_short_account_ratio__top_account_long_percent__pct1
# 24                                         feature_cgdi_index__dev_from_base__pct1
# 25        feature_top_long_short_account_ratio__top_account_long_short_ratio__pct1
# 26                                  feature_bitcoin_sth_supply__supply_z180__diff1
# 27           feature_top_long_short_account_ratio__top_account_short_percent__pct1
# 28          feature_top_long_short_account_ratio__top_account_short_percent__diff1
# 29           feature_top_long_short_account_ratio__top_account_long_percent__diff1
#
#         corr  abs_corr    n   p_value  q_value_fdr
# 0  -0.077277  0.077277  999  0.014563     0.872412
# 1  -0.075464  0.075464  999  0.017050     0.872412
# 2  -0.067279  0.067279  999  0.033485     0.872412
# 3  -0.063722  0.063722  996  0.044374     0.872412
# 4  -0.063072  0.063072  996  0.046591     0.872412
# 5  -0.062793  0.062793  999  0.047236     0.872412
# 6  -0.062793  0.062793  999  0.047236     0.872412
# 7  -0.062793  0.062793  999  0.047236     0.872412
# 8  -0.062155  0.062155  999  0.049535     0.872412
# 9  -0.062116  0.062116  999  0.049676     0.872412
# 10  0.061995  0.061995  999  0.050125     0.872412
# 11 -0.060341  0.060341  996  0.056953     0.872412
# 12 -0.060082  0.060082  999  0.057649     0.872412
# 13  0.058989  0.058989  999  0.062359     0.872412
# 14 -0.058968  0.058968  999  0.062451     0.872412
# 15  0.058739  0.058739  998  0.063609     0.872412
# 16 -0.058523  0.058523  999  0.064456     0.872412
# 17  0.057549  0.057549  749  0.115565     0.950761
# 18  0.056819  0.056819  999  0.072642     0.872412
# 19 -0.056267  0.056267  999  0.075469     0.872412
# 20 -0.056031  0.056031  996  0.077148     0.872412
# 21 -0.056031  0.056031  996  0.077148     0.872412
# 22 -0.056031  0.056031  996  0.077148     0.872412
# 23 -0.055954  0.055954  999  0.077108     0.872412
# 24  0.055338  0.055338  749  0.130252     0.950761
# 25 -0.055236  0.055236  999  0.080987     0.872412
# 26  0.055235  0.055235  996  0.081452     0.872412
# 27  0.054684  0.054684  999  0.084075     0.872412
# 28  0.054660  0.054660  999  0.084213     0.872412
# 29 -0.054635  0.054635  999  0.084351     0.872412

# %%
# Повторно пересчитываем колонку y_up_1d и убираем записи без целевой переменной
df_ml = df_all.copy()
df_ml["date"] = pd.to_datetime(df_ml["date"], errors="coerce")
df_ml = df_ml.sort_values("date").reset_index(drop=True)

close = pd.to_numeric(df_ml["close"], errors="coerce")
df_ml["y_up_1d"] = (close.shift(-1*N_DAYS) > close).astype("Int64")

df_ml = df_ml.dropna(subset=["y_up_1d", "close"]).reset_index(drop=True)

# %% [markdown]
# ## Rating of features, top 30

# %%
import numpy as np
import pandas as pd

def group_effect_report(df: pd.DataFrame, target="y_up_1d", top_n=30) -> pd.DataFrame:
    y = pd.to_numeric(df[target], errors="coerce")
    feats = [c for c in df.columns if c not in {"date", target} and pd.api.types.is_numeric_dtype(df[c])]

    rows = []
    for f in feats:
        x = pd.to_numeric(df[f], errors="coerce")
        m = x.notna() & y.notna()
        if m.sum() < 60:
            continue
        x0 = x[m & (y == 0)]
        x1 = x[m & (y == 1)]
        if len(x0) < 20 or len(x1) < 20:
            continue

        mean0, mean1 = float(x0.mean()), float(x1.mean())
        std0, std1 = float(x0.std(ddof=1)), float(x1.std(ddof=1))
        pooled = np.sqrt(((len(x0)-1)*std0**2 + (len(x1)-1)*std1**2) / (len(x0)+len(x1)-2))
        d = (mean1 - mean0) / (pooled + 1e-12)

        rows.append((f, mean1, mean0, mean1-mean0, abs(d), d, len(x1), len(x0)))

    res = pd.DataFrame(rows, columns=["feature","mean_y1","mean_y0","lift","abs_cohen_d","cohen_d","n_y1","n_y0"])
    return res.sort_values("abs_cohen_d", ascending=False).head(top_n).reset_index(drop=True)

effect_tbl = group_effect_report(df_all, target="y_up_1d", top_n=30)

# %% [markdown]
# ### Check target feature

# %%
# убедись, что нет NaN в date и что даты монотонны
df_all = df_all.sort_values("date").reset_index(drop=True)
assert df_all["date"].isna().sum() == 0
assert (pd.to_datetime(df_all["date"]).diff().dropna() >= pd.Timedelta(0)).all()

# проверка что таргет действительно завтрашний close относительно сегодняшнего
c = df_all["close"]
y_check = (c.shift(-1*N_DAYS) > c).astype("Int64")
print("y совпадает:", (y_check == df_all["y_up_1d"]).mean())
# Out:
# y совпадает: 1.0

# %% [markdown]
# ### Filter features with low coverage (a lot of Nans = low coverage)

# %%
def add_coverage(effect_tbl: pd.DataFrame, df: pd.DataFrame) -> pd.DataFrame:
    eff = effect_tbl.copy()
    eff["coverage"] = eff["feature"].apply(lambda c: float(df[c].notna().mean()) if c in df.columns else 0.0)
    return eff.sort_values(["abs_cohen_d", "coverage"], ascending=[False, False]).reset_index(drop=True)

effect_tbl_cov = add_coverage(effect_tbl, df_all)
print(effect_tbl_cov.head(30))

# Оставим только фичи с покрытием >= 0.85
good_features = effect_tbl_cov.query("coverage >= 0.85")["feature"].tolist()
print("features kept:", len(good_features))
# Out:
#                                                                            feature  \
# 0                                      feature_bitcoin_reserve_risk__log_rr__diff1
# 1                                          feature_bitcoin_sth_supply__price__pct1
# 2                                        feature_bitcoin_reserve_risk__price__pct1
# 3                                          feature_bitcoin_lth_supply__price__pct1
# 4                           feature_bitcoin_reserve_risk__reserve_risk_index__pct1
# 5                                       feature_bitcoin_reserve_risk__log_rr__pct1
# 6                                    feature_open_interest_aggregated__close__pct1
# 7          feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1
# 8                                          feature_spot_price_history__close__pct1
# 9                          feature_bitcoin_reserve_risk__reserve_risk_index__diff1
# 10      feature_global_long_short_account_ratio__global_account_long_percent__pct1
# 11                              feature_bitcoin_active_addresses__aa_slope14__pct1
# 12                                        feature_funding_rate_history__open__pct1
# 13                                  feature_bitcoin_sth_supply__supply_pct30__pct1
# 14            feature_top_long_short_account_ratio__top_account_long_percent__pct1
# 15                                     feature_coinbase_premium_index__premium_abs
# 16                                          feature_bitcoin_lth_supply__lth_supply
# 17  feature_global_long_short_account_ratio__global_account_long_short_ratio__pct1
# 18                       feature_liquidation_history__short_liquidation_usd__diff1
# 19    feature_global_long_short_account_ratio__global_account_short_percent__diff1
# 20     feature_global_long_short_account_ratio__global_account_long_percent__diff1
# 21     feature_top_long_short_position_ratio__top_position_long_short_ratio__diff1
# 22        feature_top_long_short_account_ratio__top_account_long_short_ratio__pct1
# 23                                     feature_open_interest_aggregated__low__pct1
# 24          feature_top_long_short_account_ratio__top_account_short_percent__diff1
# 25           feature_top_long_short_account_ratio__top_account_long_percent__diff1
# 26                       feature_bitfinex_margin_long_short__log_long_short__diff1
# 27                                    feature_bitcoin_reserve_risk__rr_z180__diff1
# 28      feature_top_long_short_position_ratio__top_position_long_short_ratio__pct1
# 29         feature_top_long_short_position_ratio__top_position_short_percent__pct1
#
#          mean_y1       mean_y0          lift  abs_cohen_d   cohen_d  n_y1  \
# 0  -1.287529e-03  1.932722e-03 -3.220251e-03     0.137009 -0.137009   507
# 1  -1.553940e-04  3.058964e-03 -3.214358e-03     0.136055 -0.136055   508
# 2  -1.553940e-04  3.058964e-03 -3.214358e-03     0.136055 -0.136055   508
# 3  -1.553940e-04  3.058964e-03 -3.214358e-03     0.136055 -0.136055   508
# 4  -9.854254e-04  2.202785e-03 -3.188211e-03     0.135278 -0.135278   508
# 5   2.071197e-04 -2.956566e-04  5.027762e-04     0.133823  0.133823   508
# 6   1.349937e-04  4.301713e-03 -4.166720e-03     0.131802 -0.131802   508
# 7  -8.033372e+05  8.172636e+05 -1.620601e+06     0.127602 -0.127602   508
# 8  -6.257639e-05  2.907402e-03 -2.969978e-03     0.125189 -0.125189   508
# 9  -2.422242e-06  3.413497e-06 -5.835738e-06     0.123143 -0.123143   507
# 10 -8.450332e-04  1.149454e-02 -1.233957e-02     0.123078 -0.123078   508
# 11 -1.245865e+00  5.838436e-01 -1.829709e+00     0.122383 -0.122383   508
# 12 -1.745074e+00  4.582724e-01 -2.203346e+00     0.120488 -0.120488   508
# 13 -8.435628e-02  3.853790e-01 -4.697352e-01     0.118110 -0.118110   508
# 14 -7.342236e-04  1.026977e-02 -1.100399e-02     0.117294 -0.117294   508
# 15  3.258008e+01  2.887297e+01  3.707111e+00     0.116673  0.116673   508
# 16  1.533827e+07  1.526968e+07  6.859308e+04     0.113894  0.113894   508
# 17  1.398299e-02  4.090520e-02 -2.692221e-02     0.113690 -0.113690   508
# 18 -5.642916e+05  5.728206e+05 -1.137112e+06     0.111576 -0.111576   508
# 19  2.801575e-01 -3.169450e-01  5.971025e-01     0.109295  0.109295   508
# 20 -2.801575e-01  3.169450e-01 -5.971025e-01     0.109295 -0.109295   508
# 21 -4.488189e-03  6.843177e-03 -1.133137e-02     0.108963 -0.108963   508
# 22  1.398650e-02  3.919587e-02 -2.520937e-02     0.108521 -0.108521   508
# 23  4.179414e-04  4.763957e-03 -4.346016e-03     0.106981 -0.106981   508
# 24  2.590354e-01 -3.046232e-01  5.636587e-01     0.106123  0.106123   508
# 25 -2.590354e-01  3.046232e-01 -5.636587e-01     0.106123 -0.106123   508
# 26 -9.404134e-03  1.191919e-02 -2.132333e-02     0.103036 -0.103036   508
# 27 -1.367687e-02  8.322539e-03 -2.199941e-02     0.101196 -0.101196   507
# 28 -5.370753e-04  5.886450e-03 -6.423525e-03     0.100691 -0.100691   508
# 29  2.205682e-03 -1.609484e-03  3.815166e-03     0.100116  0.100116   508
#
#     n_y0  coverage
# 0    489     0.996
# 1    491     0.999
# 2    491     0.999
# 3    491     0.999
# 4    491     0.999
# 5    491     0.999
# 6    491     0.999
# 7    491     0.999
# 8    491     0.999
# 9    489     0.996
# 10   491     0.999
# 11   491     0.999
# 12   491     0.999
# 13   491     0.999
# 14   491     0.999
# 15   492     1.000
# 16   490     0.998
# 17   491     0.999
# 18   491     0.999
# 19   491     0.999
# 20   491     0.999
# 21   491     0.999
# 22   491     0.999
# 23   491     0.999
# 24   491     0.999
# 25   491     0.999
# 26   491     0.999
# 27   489     0.996
# 28   491     0.999
# 29   491     0.999
# features kept: 30

# %% [markdown]
# ## Learning Logistic Regression

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

from sklearn.model_selection import TimeSeriesSplit
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score

def walk_forward_logreg(
    df: pd.DataFrame,
    features: list[str],
    target: str = "y_up_1d",
    n_splits: int = 5,
    thr: float = 0.5,
):
    d = df.copy()
    d["date"] = pd.to_datetime(d["date"], errors="coerce")
    d = d.sort_values("date", kind="stable").reset_index(drop=True)

    X = d[features].copy()
    y = pd.to_numeric(d[target], errors="coerce")

    m = y.notna() & X.notna().any(axis=1)
    X, y = X.loc[m].reset_index(drop=True), y.loc[m].astype(int).reset_index(drop=True)

    tscv = TimeSeriesSplit(n_splits=n_splits)

    pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="mean")),
        ("scaler", StandardScaler()),
        ("clf", LogisticRegression(max_iter=3000, class_weight="balanced")),
    ])

    accs, aucs, precs, recs = [], [], [], []
    for train_idx, test_idx in tscv.split(X):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        pipe.fit(X_train, y_train)
        proba = pipe.predict_proba(X_test)[:, 1]
        pred = (proba >= thr).astype(int)

        accs.append(accuracy_score(y_test, pred))
        precs.append(precision_score(y_test, pred, zero_division=0))
        recs.append(recall_score(y_test, pred, zero_division=0))

        # ROC AUC: если один класс — ставим nan, но длину сохраняем
        if len(np.unique(y_test)) == 2:
            aucs.append(roc_auc_score(y_test, proba))
        else:
            aucs.append(np.nan)

    return {
        "n_features": len(features),
        "thr": thr,
        "acc_mean": float(np.nanmean(accs)),
        "acc_splits": accs,
        "precision_mean": float(np.nanmean(precs)),
        "precision_splits": precs,
        "recall_mean": float(np.nanmean(recs)),
        "recall_splits": recs,
        "auc_mean": float(np.nanmean(aucs)),
        "auc_splits": aucs,
    }


def print_metrics(res: dict, title: str = "RESULTS"):
    print(f"\n{title}")
    print(f"thr={res['thr']} | n_features={res['n_features']}")
    print(f"Precision: {res['precision_mean']:.4f} | splits: {np.round(res['precision_splits'], 4)}")
    print(f"Recall:    {res['recall_mean']:.4f} | splits: {np.round(res['recall_splits'], 4)}")
    print(f"ROC AUC:   {res['auc_mean']:.4f} | splits: {np.round(res['auc_splits'], 4)}")

# %%
# Range model

def add_range_target(
    df: pd.DataFrame,
    high_col: str,
    low_col: str,
    close_col: str | None = None,   # если хочешь дополнительно range_pct
    date_col: str = "date",
    ma_window: int = 14,
    horizon: int = 1,               # N дней вперед для таргета
    use_pct: bool = False,          # False: high-low, True: (high-low)/close
    baseline_shift: int = 1,        # 1 => SMA только по прошлым дням (без leakage)
    out_target_col: str | None = None,
) -> pd.DataFrame:
    d = df.copy()
    d[date_col] = pd.to_datetime(d[date_col], errors="coerce")
    d = d.sort_values(date_col, kind="stable").reset_index(drop=True)

    hi = pd.to_numeric(d[high_col], errors="coerce")
    lo = pd.to_numeric(d[low_col], errors="coerce")
    rng = hi - lo

    d["range_abs"] = rng

    if close_col is not None:
        close = pd.to_numeric(d[close_col], errors="coerce")
        d["range_pct"] = rng / close
    else:
        d["range_pct"] = np.nan

    # выбираем, на чем строим таргет и baseline
    base_series = d["range_pct"] if use_pct else d["range_abs"]
    base_name = "range_pct" if use_pct else "range_abs"

    # baseline SMA(14) — только прошлое (shift=1)
    d[f"{base_name}_ma{ma_window}"] = (
        base_series.shift(baseline_shift).rolling(ma_window, min_periods=ma_window).mean()
    )

    # будущий range на горизонте N
    fut = base_series.shift(-horizon)

    # бинарный таргет: будущий range выше/ниже текущей SMA(14)
    y = np.where(
        fut.notna() & d[f"{base_name}_ma{ma_window}"].notna(),
        (fut > d[f"{base_name}_ma{ma_window}"]).astype(int),
        np.nan,
    )

    if out_target_col is None:
        out_target_col = f"y_range_up_{base_name}_N{horizon}_ma{ma_window}"

    d[out_target_col] = y
    return d

# %%
for col in df_all.columns:
    print(col)
# Out:
# feature_open_interest_history__open
# feature_open_interest_history__high
# feature_open_interest_history__low
# feature_open_interest_history__close
# date
# feature_open_interest_aggregated__open
# feature_open_interest_aggregated__high
# feature_open_interest_aggregated__low
# feature_open_interest_aggregated__close
# feature_open_interest_stablecoin__open
# feature_open_interest_stablecoin__high
# feature_open_interest_stablecoin__low
# feature_open_interest_stablecoin__close
# feature_open_interest_coin_margin__open
# feature_open_interest_coin_margin__high
# feature_open_interest_coin_margin__low
# feature_open_interest_coin_margin__close
# feature_funding_rate_history__open
# feature_funding_rate_history__high
# feature_funding_rate_history__low
# feature_funding_rate_history__close
# feature_funding_rate_oi_weight__open
# feature_funding_rate_oi_weight__high
# feature_funding_rate_oi_weight__low
# feature_funding_rate_oi_weight__close
# feature_funding_rate_vol_weight__open
# feature_funding_rate_vol_weight__high
# feature_funding_rate_vol_weight__low
# feature_funding_rate_vol_weight__close
# feature_global_long_short_account_ratio__global_account_long_percent
# feature_global_long_short_account_ratio__global_account_short_percent
# feature_global_long_short_account_ratio__global_account_long_short_ratio
# feature_top_long_short_account_ratio__top_account_long_percent
# feature_top_long_short_account_ratio__top_account_short_percent
# feature_top_long_short_account_ratio__top_account_long_short_ratio
# feature_top_long_short_position_ratio__top_position_long_percent
# feature_top_long_short_position_ratio__top_position_short_percent
# feature_top_long_short_position_ratio__top_position_long_short_ratio
# feature_net_position__net_long_change
# feature_net_position__net_short_change
# feature_liquidation_history__long_liquidation_usd
# feature_liquidation_history__short_liquidation_usd
# feature_liquidation_aggregated__aggregated_long_liquidation_usd
# feature_liquidation_aggregated__aggregated_short_liquidation_usd
# feature_orderbook_ask_bids__bids_usd
# feature_orderbook_ask_bids__bids_quantity
# feature_orderbook_ask_bids__asks_usd
# feature_orderbook_ask_bids__asks_quantity
# feature_orderbook_aggregated__aggregated_bids_usd
# feature_orderbook_aggregated__aggregated_bids_quantity
# feature_orderbook_aggregated__aggregated_asks_usd
# feature_orderbook_aggregated__aggregated_asks_quantity
# feature_taker_buy_sell_volume__taker_buy_volume_usd
# feature_taker_buy_sell_volume__taker_sell_volume_usd
# feature_taker_buy_sell_volume_aggregated__aggregated_buy_volume_usd
# feature_taker_buy_sell_volume_aggregated__aggregated_sell_volume_usd
# open
# high
# low
# close
# volume_usd
# feature_bitcoin_lth_supply__price
# feature_bitcoin_lth_supply__lth_supply
# feature_bitcoin_lth_supply__supply_pct30
# feature_bitcoin_lth_supply__supply_z180
# feature_bitcoin_lth_supply__supply_slope14
# feature_bitcoin_active_addresses__price
# feature_bitcoin_active_addresses__active_address_count
# feature_bitcoin_active_addresses__aa_pct7
# feature_bitcoin_active_addresses__aa_z180
# feature_bitcoin_active_addresses__aa_slope14
# feature_bitcoin_sth_supply__price
# feature_bitcoin_sth_supply__sth_supply
# feature_bitcoin_sth_supply__supply_pct30
# feature_bitcoin_sth_supply__supply_z180
# feature_bitcoin_sth_supply__supply_slope14
# feature_bitcoin_reserve_risk__price
# feature_bitcoin_reserve_risk__reserve_risk_index
# feature_bitcoin_reserve_risk__movcd
# feature_bitcoin_reserve_risk__hodl_bank
# feature_bitcoin_reserve_risk__vocd
# feature_bitcoin_reserve_risk__log_rr
# feature_bitcoin_reserve_risk__rr_z180
# feature_bitcoin_reserve_risk__rr_slope14
# feature_bitfinex_margin_long_short__long_quantity
# feature_bitfinex_margin_long_short__short_quantity
# feature_bitfinex_margin_long_short__total_qty
# feature_bitfinex_margin_long_short__long_share
# feature_bitfinex_margin_long_short__log_long_short
# feature_coinbase_premium_index__premium
# feature_coinbase_premium_index__premium_rate
# feature_coinbase_premium_index__premium_abs
# feature_coinbase_premium_index__premium_softsign
# feature_coinbase_premium_index__premium_rate_bps
# feature_coinbase_premium_index__implied_ref_price
# feature_cgdi_index__index_value
# feature_cgdi_index__log_level
# feature_cgdi_index__dev_from_base
# feature_cgdi_index__dev_softsign
# y_up_1d
# feature_open_interest_history__open__diff1
# feature_open_interest_history__open__pct1
# feature_open_interest_history__high__diff1
# feature_open_interest_history__high__pct1
# feature_open_interest_history__low__diff1
# feature_open_interest_history__low__pct1
# feature_open_interest_history__close__diff1
# feature_open_interest_history__close__pct1
# feature_open_interest_aggregated__open__diff1
# feature_open_interest_aggregated__open__pct1
# feature_open_interest_aggregated__high__diff1
# feature_open_interest_aggregated__high__pct1
# feature_open_interest_aggregated__low__diff1
# feature_open_interest_aggregated__low__pct1
# feature_open_interest_aggregated__close__diff1
# feature_open_interest_aggregated__close__pct1
# feature_open_interest_stablecoin__open__diff1
# feature_open_interest_stablecoin__open__pct1
# feature_open_interest_stablecoin__high__diff1
# feature_open_interest_stablecoin__high__pct1
# feature_open_interest_stablecoin__low__diff1
# feature_open_interest_stablecoin__low__pct1
# feature_open_interest_stablecoin__close__diff1
# feature_open_interest_stablecoin__close__pct1
# feature_open_interest_coin_margin__open__diff1
# feature_open_interest_coin_margin__open__pct1
# feature_open_interest_coin_margin__high__diff1
# feature_open_interest_coin_margin__high__pct1
# feature_open_interest_coin_margin__low__diff1
# feature_open_interest_coin_margin__low__pct1
# feature_open_interest_coin_margin__close__diff1
# feature_open_interest_coin_margin__close__pct1
# feature_funding_rate_history__open__diff1
# feature_funding_rate_history__open__pct1
# feature_funding_rate_history__high__diff1
# feature_funding_rate_history__high__pct1
# feature_funding_rate_history__low__diff1
# feature_funding_rate_history__low__pct1
# feature_funding_rate_history__close__diff1
# feature_funding_rate_history__close__pct1
# feature_funding_rate_oi_weight__open__diff1
# feature_funding_rate_oi_weight__open__pct1
# feature_funding_rate_oi_weight__high__diff1
# feature_funding_rate_oi_weight__high__pct1
# feature_funding_rate_oi_weight__low__diff1
# feature_funding_rate_oi_weight__low__pct1
# feature_funding_rate_oi_weight__close__diff1
# feature_funding_rate_oi_weight__close__pct1
# feature_funding_rate_vol_weight__open__diff1
# feature_funding_rate_vol_weight__open__pct1
# feature_funding_rate_vol_weight__high__diff1
# feature_funding_rate_vol_weight__high__pct1
# feature_funding_rate_vol_weight__low__diff1
# feature_funding_rate_vol_weight__low__pct1
# feature_funding_rate_vol_weight__close__diff1
# feature_funding_rate_vol_weight__close__pct1
# feature_global_long_short_account_ratio__global_account_long_percent__diff1
# feature_global_long_short_account_ratio__global_account_long_percent__pct1
# feature_global_long_short_account_ratio__global_account_short_percent__diff1
# feature_global_long_short_account_ratio__global_account_short_percent__pct1
# feature_global_long_short_account_ratio__global_account_long_short_ratio__diff1
# feature_global_long_short_account_ratio__global_account_long_short_ratio__pct1
# feature_top_long_short_account_ratio__top_account_long_percent__diff1
# feature_top_long_short_account_ratio__top_account_long_percent__pct1
# feature_top_long_short_account_ratio__top_account_short_percent__diff1
# feature_top_long_short_account_ratio__top_account_short_percent__pct1
# feature_top_long_short_account_ratio__top_account_long_short_ratio__diff1
# feature_top_long_short_account_ratio__top_account_long_short_ratio__pct1
# feature_top_long_short_position_ratio__top_position_long_percent__diff1
# feature_top_long_short_position_ratio__top_position_long_percent__pct1
# feature_top_long_short_position_ratio__top_position_short_percent__diff1
# feature_top_long_short_position_ratio__top_position_short_percent__pct1
# feature_top_long_short_position_ratio__top_position_long_short_ratio__diff1
# feature_top_long_short_position_ratio__top_position_long_short_ratio__pct1
# feature_net_position__net_long_change__diff1
# feature_net_position__net_long_change__pct1
# feature_net_position__net_short_change__diff1
# feature_net_position__net_short_change__pct1
# feature_liquidation_history__long_liquidation_usd__diff1
# feature_liquidation_history__long_liquidation_usd__pct1
# feature_liquidation_history__short_liquidation_usd__diff1
# feature_liquidation_history__short_liquidation_usd__pct1
# feature_liquidation_aggregated__aggregated_long_liquidation_usd__diff1
# feature_liquidation_aggregated__aggregated_long_liquidation_usd__pct1
# feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1
# feature_liquidation_aggregated__aggregated_short_liquidation_usd__pct1
# feature_orderbook_ask_bids__bids_usd__diff1
# feature_orderbook_ask_bids__bids_usd__pct1
# feature_orderbook_ask_bids__bids_quantity__diff1
# feature_orderbook_ask_bids__bids_quantity__pct1
# feature_orderbook_ask_bids__asks_usd__diff1
# feature_orderbook_ask_bids__asks_usd__pct1
# feature_orderbook_ask_bids__asks_quantity__diff1
# feature_orderbook_ask_bids__asks_quantity__pct1
# feature_orderbook_aggregated__aggregated_bids_usd__diff1
# feature_orderbook_aggregated__aggregated_bids_usd__pct1
# feature_orderbook_aggregated__aggregated_bids_quantity__diff1
# feature_orderbook_aggregated__aggregated_bids_quantity__pct1
# feature_orderbook_aggregated__aggregated_asks_usd__diff1
# feature_orderbook_aggregated__aggregated_asks_usd__pct1
# feature_orderbook_aggregated__aggregated_asks_quantity__diff1
# feature_orderbook_aggregated__aggregated_asks_quantity__pct1
# feature_taker_buy_sell_volume__taker_buy_volume_usd__diff1
# feature_taker_buy_sell_volume__taker_buy_volume_usd__pct1
# feature_taker_buy_sell_volume__taker_sell_volume_usd__diff1
# feature_taker_buy_sell_volume__taker_sell_volume_usd__pct1
# feature_taker_buy_sell_volume_aggregated__aggregated_buy_volume_usd__diff1
# feature_taker_buy_sell_volume_aggregated__aggregated_buy_volume_usd__pct1
# feature_taker_buy_sell_volume_aggregated__aggregated_sell_volume_usd__diff1
# feature_taker_buy_sell_volume_aggregated__aggregated_sell_volume_usd__pct1
# feature_spot_price_history__open__diff1
# feature_spot_price_history__open__pct1
# feature_spot_price_history__high__diff1
# feature_spot_price_history__high__pct1
# feature_spot_price_history__low__diff1
# feature_spot_price_history__low__pct1
# feature_spot_price_history__close__diff1
# feature_spot_price_history__close__pct1
# feature_spot_price_history__volume_usd__diff1
# feature_spot_price_history__volume_usd__pct1
# feature_bitcoin_lth_supply__price__diff1
# feature_bitcoin_lth_supply__price__pct1
# feature_bitcoin_lth_supply__lth_supply__diff1
# feature_bitcoin_lth_supply__lth_supply__pct1
# feature_bitcoin_lth_supply__supply_pct30__diff1
# feature_bitcoin_lth_supply__supply_pct30__pct1
# feature_bitcoin_lth_supply__supply_z180__diff1
# feature_bitcoin_lth_supply__supply_z180__pct1
# feature_bitcoin_lth_supply__supply_slope14__diff1
# feature_bitcoin_lth_supply__supply_slope14__pct1
# feature_bitcoin_active_addresses__price__diff1
# feature_bitcoin_active_addresses__price__pct1
# feature_bitcoin_active_addresses__active_address_count__diff1
# feature_bitcoin_active_addresses__active_address_count__pct1
# feature_bitcoin_active_addresses__aa_pct7__diff1
# feature_bitcoin_active_addresses__aa_pct7__pct1
# feature_bitcoin_active_addresses__aa_z180__diff1
# feature_bitcoin_active_addresses__aa_z180__pct1
# feature_bitcoin_active_addresses__aa_slope14__diff1
# feature_bitcoin_active_addresses__aa_slope14__pct1
# feature_bitcoin_sth_supply__price__diff1
# feature_bitcoin_sth_supply__price__pct1
# feature_bitcoin_sth_supply__sth_supply__diff1
# feature_bitcoin_sth_supply__sth_supply__pct1
# feature_bitcoin_sth_supply__supply_pct30__diff1
# feature_bitcoin_sth_supply__supply_pct30__pct1
# feature_bitcoin_sth_supply__supply_z180__diff1
# feature_bitcoin_sth_supply__supply_z180__pct1
# feature_bitcoin_sth_supply__supply_slope14__diff1
# feature_bitcoin_sth_supply__supply_slope14__pct1
# feature_bitcoin_reserve_risk__price__diff1
# feature_bitcoin_reserve_risk__price__pct1
# feature_bitcoin_reserve_risk__reserve_risk_index__diff1
# feature_bitcoin_reserve_risk__reserve_risk_index__pct1
# feature_bitcoin_reserve_risk__movcd__diff1
# feature_bitcoin_reserve_risk__movcd__pct1
# feature_bitcoin_reserve_risk__hodl_bank__diff1
# feature_bitcoin_reserve_risk__hodl_bank__pct1
# feature_bitcoin_reserve_risk__vocd__diff1
# feature_bitcoin_reserve_risk__vocd__pct1
# feature_bitcoin_reserve_risk__log_rr__diff1
# feature_bitcoin_reserve_risk__log_rr__pct1
# feature_bitcoin_reserve_risk__rr_z180__diff1
# feature_bitcoin_reserve_risk__rr_z180__pct1
# feature_bitcoin_reserve_risk__rr_slope14__diff1
# feature_bitcoin_reserve_risk__rr_slope14__pct1
# feature_bitfinex_margin_long_short__long_quantity__diff1
# feature_bitfinex_margin_long_short__long_quantity__pct1
# feature_bitfinex_margin_long_short__short_quantity__diff1
# feature_bitfinex_margin_long_short__short_quantity__pct1
# feature_bitfinex_margin_long_short__total_qty__diff1
# feature_bitfinex_margin_long_short__total_qty__pct1
# feature_bitfinex_margin_long_short__long_share__diff1
# feature_bitfinex_margin_long_short__long_share__pct1
# feature_bitfinex_margin_long_short__log_long_short__diff1
# feature_bitfinex_margin_long_short__log_long_short__pct1
# feature_coinbase_premium_index__premium__diff1
# feature_coinbase_premium_index__premium__pct1
# feature_coinbase_premium_index__premium_rate__diff1
# feature_coinbase_premium_index__premium_rate__pct1
# feature_coinbase_premium_index__premium_abs__diff1
# feature_coinbase_premium_index__premium_abs__pct1
# feature_coinbase_premium_index__premium_softsign__diff1
# feature_coinbase_premium_index__premium_softsign__pct1
# feature_coinbase_premium_index__premium_rate_bps__diff1
# feature_coinbase_premium_index__premium_rate_bps__pct1
# feature_coinbase_premium_index__implied_ref_price__diff1
# feature_coinbase_premium_index__implied_ref_price__pct1
# feature_cgdi_index__index_value__diff1
# feature_cgdi_index__index_value__pct1
# feature_cgdi_index__log_level__diff1
# feature_cgdi_index__log_level__pct1
# feature_cgdi_index__dev_from_base__diff1
# feature_cgdi_index__dev_from_base__pct1
# feature_cgdi_index__dev_softsign__diff1
# feature_cgdi_index__dev_softsign__pct1

# %%
# BASE фичи для одного дня (исправленные названия!)
base_feats = [
    "spot_price_history__close__pct1",
    "spot_price_history__close__diff1",
    "futures_open_interest_aggregated_history__close__pct1",
    "futures_liquidation_aggregated_history__aggregated_short_liquidation_usd__diff1",
    "futures_global_long_short_account_ratio_history__global_account_long_percent",
    "futures_top_long_short_account_ratio_history__top_account_long_short_ratio",
    "coinbase_premium__premium__diff1",
    "coinbase_premium__premium_abs"
    ]

# %%
HIGH_COL  = "high"
LOW_COL   = "low"
CLOSE_COL = "close"


d_rngp = add_range_target(
    df_all,
    high_col=HIGH_COL,
    low_col=LOW_COL,
    close_col=CLOSE_COL,
    ma_window=14,
    horizon=1,
    use_pct=True,      # (high-low)/close
    baseline_shift=1,
)

target_col = "y_range_up_range_pct_N1_ma14"

range_feats = [
    "range_pct",
    "range_pct_ma14",
]
feat_set = [c for c in (base_feats + range_feats) if c in d_rngp.columns]

# res_rngp = walk_forward_logreg(d_rngp, features=feat_set, target=target_col, n_splits=5, thr=0.5)
# print(res_rngp)
res_rngp = walk_forward_logreg(d_rngp, features=feat_set, target=target_col, n_splits=5, thr=0.5)
res_rngp
# Out:
# {'n_features': 10,
#  'thr': 0.5,
#  'acc_mean': 0.6060975609756097,
#  'acc_splits': [0.6280487804878049,
#   0.5853658536585366,
#   0.6219512195121951,
#   0.5792682926829268,
#   0.6158536585365854],
#  'precision_mean': 0.5371718278921527,
#  'precision_splits': [0.6153846153846154,
#   0.49122807017543857,
#   0.5466666666666666,
#   0.46875,
#   0.5638297872340425],
#  'recall_mean': 0.5551845740242884,
#  'recall_splits': [0.34285714285714286,
#   0.417910447761194,
#   0.5942028985507246,
#   0.7142857142857143,
#   0.7066666666666667],
#  'auc_mean': 0.6595705783313311,
#  'auc_splits': [0.6133738601823708,
#   0.6211724880750885,
#   0.7035850495804729,
#   0.7087851642307087,
#   0.650936329588015]}

# %%
# prediction models
def add_lags(df: pd.DataFrame, cols: list[str], lags=(1, 2)) -> pd.DataFrame:
    out = df.copy()
    out["date"] = pd.to_datetime(out["date"], errors="coerce")
    out = out.sort_values("date", kind="stable").reset_index(drop=True)
    for c in cols:
        if c in out.columns:
            x = pd.to_numeric(out[c], errors="coerce")
            for L in lags:
                out[f"{c}__lag{L}"] = x.shift(L)
    return out

# base_feats = ['index_btc_reserve_risk__log_rr__diff1',
#        'index_btc_sth_supply__price__pct1',
#        'index_btc_reserve_risk__price__pct1',
#        'index_btc_lth_supply__price__pct1',
#        'index_btc_reserve_risk__reserve_risk_index__pct1',
#        'futures_open_interest_aggregated_history__close__pct1',
#        'index_btc_reserve_risk__log_rr__pct1',
#        'spot_price_history__close__pct1',
#        'index_btc_reserve_risk__reserve_risk_index__diff1',
#        'futures_liquidation_aggregated_history__aggregated_short_liquidation_usd__diff1',
#        'futures_funding_rate_history__open__pct1',
#        'index_btc_active_addresses__aa_slope14__pct1'
#        ]

# base фичи для 3 дней
# base_feats = [
#     "spot_price_history__close__pct1",
#     "spot_price_history__close__diff1",
#     'feat__orderbook_imbalance_usd',
#     'futures_liquidation_aggregated_history__aggregated_short_liquidation_usd__diff1'
#     'futures_open_interest_aggregated_stablecoin_history__close',
#     'futures_open_interest_aggregated_stablecoin_history__low',
#     'cgdi_log_level', 'cgdi_dev_softsign', 'cgdi_dev_from_base',
#     'cgdi_index_value'
# ]

# base фичи для 4 days
# base_feats = [
#     'futures_open_interest_aggregated_stablecoin_history__close',
#        'feat__orderbook_imbalance_usd',
#        'futures_open_interest_aggregated_stablecoin_history__low',
#        'futures_open_interest_history__low__diff1',
#        'futures_open_interest_aggregated_stablecoin_history__open',
#        'cgdi_dev_from_base', 'cgdi_index_value',
#        'futures_open_interest_aggregated_stablecoin_history__high',
#        'cgdi_log_level', 'cgdi_dev_softsign'
# ]

# base features for 5 days
# base_feats = [
#     'cgdi_dev_from_base', 'cgdi_index_value', 'cgdi_log_level',
#        'cgdi_dev_softsign',
#        'futures_open_interest_aggregated_stablecoin_history__close',
#        'futures_open_interest_aggregated_stablecoin_history__low',
#        'futures_open_interest_aggregated_stablecoin_history__high',
#        'futures_open_interest_aggregated_stablecoin_history__open',
#        'futures_orderbook_aggregated_ask_bids_history__aggregated_asks_usd__pct1',
#        'futures_orderbook_ask_bids_history__asks_usd__pct1'
# ]

# base features for 7 days
# base_feats = [
#     'cgdi_dev_from_base', 'cgdi_index_value', 'cgdi_log_level',
#        'cgdi_dev_softsign',
#        'futures_open_interest_aggregated_stablecoin_history__close',
#        'futures_open_interest_aggregated_stablecoin_history__low',
#        'futures_open_interest_aggregated_stablecoin_history__high',
#        'futures_open_interest_aggregated_stablecoin_history__open',
#        'futures_orderbook_aggregated_ask_bids_history__aggregated_asks_usd__pct1',
#        'futures_orderbook_ask_bids_history__asks_usd__pct1'
# ]

base_feats = [c for c in base_feats if c in df_all.columns]

# какие из них деривативные (кроме спота) — на них делаем лаги
deriv = [c for c in base_feats if not c.startswith("spot_price_history__")]

df_lag = add_lags(df_all, cols=deriv, lags=(1, 2, 3 ,5))

lag_feats = (
    base_feats
    + [f"{c}__lag1" for c in deriv]
    + [f"{c}__lag2" for c in deriv]
    + [f"{c}__lag3" for c in deriv]
    + [f"{c}__lag5" for c in deriv]  # было lag4, но ты создаёшь lag5
)
lag_feats = [c for c in lag_feats if c in df_lag.columns]

print("BASE feats:", base_feats)
print("LAG feats:", lag_feats)

res_base = walk_forward_logreg(df_all, base_feats, n_splits=5, thr=0.5)
res_lag  = walk_forward_logreg(df_lag, lag_feats, n_splits=5, thr=0.5)

print("\nBASE:", res_base)
print("\nLAG :", res_lag)
# Out:
# BASE feats: ['feature_spot_price_history__close__pct1', 'feature_spot_price_history__close__diff1', 'feature_open_interest_aggregated__close__pct1', 'feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1', 'feature_global_long_short_account_ratio__global_account_long_percent', 'feature_top_long_short_account_ratio__top_account_long_short_ratio', 'feature_coinbase_premium_index__premium__diff1', 'feature_coinbase_premium_index__premium_abs']
# LAG feats: ['feature_spot_price_history__close__pct1', 'feature_spot_price_history__close__diff1', 'feature_open_interest_aggregated__close__pct1', 'feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1', 'feature_global_long_short_account_ratio__global_account_long_percent', 'feature_top_long_short_account_ratio__top_account_long_short_ratio', 'feature_coinbase_premium_index__premium__diff1', 'feature_coinbase_premium_index__premium_abs', 'feature_open_interest_aggregated__close__pct1__lag1', 'feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1__lag1', 'feature_global_long_short_account_ratio__global_account_long_percent__lag1', 'feature_top_long_short_account_ratio__top_account_long_short_ratio__lag1', 'feature_coinbase_premium_index__premium__diff1__lag1', 'feature_coinbase_premium_index__premium_abs__lag1', 'feature_open_interest_aggregated__close__pct1__lag2', 'feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1__lag2', 'feature_global_long_short_account_ratio__global_account_long_percent__lag2', 'feature_top_long_short_account_ratio__top_account_long_short_ratio__lag2', 'feature_coinbase_premium_index__premium__diff1__lag2', 'feature_coinbase_premium_index__premium_abs__lag2', 'feature_open_interest_aggregated__close__pct1__lag3', 'feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1__lag3', 'feature_global_long_short_account_ratio__global_account_long_percent__lag3', 'feature_top_long_short_account_ratio__top_account_long_short_ratio__lag3', 'feature_coinbase_premium_index__premium__diff1__lag3', 'feature_coinbase_premium_index__premium_abs__lag3', 'feature_open_interest_aggregated__close__pct1__lag5', 'feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1__lag5', 'feature_global_long_short_account_ratio__global_account_long_percent__lag5', 'feature_top_long_short_account_ratio__top_account_long_short_ratio__lag5', 'feature_coinbase_premium_index__premium__diff1__lag5', 'feature_coinbase_premium_index__premium_abs__lag5']
#
# BASE: {'n_features': 8, 'thr': 0.5, 'acc_mean': 0.5048192771084337, 'acc_splits': [0.4939759036144578, 0.5180722891566265, 0.5120481927710844, 0.5180722891566265, 0.4819277108433735], 'precision_mean': 0.5396825415127762, 'precision_splits': [0.6744186046511628, 0.49557522123893805, 0.5288461538461539, 0.5271317829457365, 0.47244094488188976], 'recall_mean': 0.6350153653514632, 'recall_splits': [0.29292929292929293, 0.7088607594936709, 0.632183908045977, 0.7816091954022989, 0.759493670886076], 'auc_mean': 0.5487578443115033, 'auc_splits': [0.5835971656867179, 0.5495416848537756, 0.5240797322857559, 0.5294631165429943, 0.557107522188273]}
#
# LAG : {'n_features': 32, 'thr': 0.5, 'acc_mean': 0.4915662650602409, 'acc_splits': [0.4397590361445783, 0.5120481927710844, 0.4939759036144578, 0.5120481927710844, 0.5], 'precision_mean': 0.5176234230331908, 'precision_splits': [0.5652173913043478, 0.49, 0.5205479452054794, 0.5340909090909091, 0.4782608695652174], 'recall_mean': 0.48337058935051075, 'recall_splits': [0.26262626262626265, 0.620253164556962, 0.4367816091954023, 0.5402298850574713, 0.5569620253164557], 'auc_mean': 0.513570501789164, 'auc_splits': [0.5035428916025931, 0.5056016295649643, 0.4986177797177361, 0.5245162229012077, 0.5355739851593191]}

# %%
import warnings
warnings.filterwarnings("ignore")
from tqdm import tqdm

import numpy as np
import pandas as pd

from sklearn.model_selection import TimeSeriesSplit
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score


# --------- CV eval (one config) ----------
def walk_forward_logreg_cfg(
    df: pd.DataFrame,
    features: list[str],
    target: str = "y_up_1d",
    n_splits: int = 5,
    thr: float = 0.5,
    imputer_strategy: str = "mean",          # "mean" | "median"
    C: float = 1.0,
    penalty: str = "l2",                     # "l1" | "l2" | "elasticnet"
    solver: str = "lbfgs",                   # lbfgs/liblinear/saga
    l1_ratio: float | None = None,           # only for elasticnet+saga
    class_weight: str | dict | None = "balanced",
):
    d = df.copy()
    d["date"] = pd.to_datetime(d["date"], errors="coerce")
    d = d.sort_values("date", kind="stable").reset_index(drop=True)

    X = d[features].copy()
    y = pd.to_numeric(d[target], errors="coerce")

    m = y.notna() & X.notna().any(axis=1)
    X, y = X.loc[m].reset_index(drop=True), y.loc[m].astype(int).reset_index(drop=True)

    tscv = TimeSeriesSplit(n_splits=n_splits)

    clf_kwargs = dict(
        max_iter=4000,
        class_weight=class_weight,
        C=float(C),
        penalty=penalty,
        solver=solver,
    )
    if penalty == "elasticnet":
        clf_kwargs["l1_ratio"] = float(l1_ratio if l1_ratio is not None else 0.5)

    pipe = Pipeline([
        ("imputer", SimpleImputer(strategy=imputer_strategy)),
        ("scaler", StandardScaler()),
        ("clf", LogisticRegression(**clf_kwargs)),
    ])

    accs, aucs, precs, recs = [], [], [], []
    for tr, te in tscv.split(X):
        X_tr, X_te = X.iloc[tr], X.iloc[te]
        y_tr, y_te = y.iloc[tr], y.iloc[te]

        pipe.fit(X_tr, y_tr)
        proba = pipe.predict_proba(X_te)[:, 1]
        pred = (proba >= thr).astype(int)

        accs.append(accuracy_score(y_te, pred))
        precs.append(precision_score(y_te, pred, zero_division=0))
        recs.append(recall_score(y_te, pred, zero_division=0))

        if y_te.nunique() == 2:
            aucs.append(roc_auc_score(y_te, proba))

    return {
        "thr": thr,
        "imputer": imputer_strategy,
        "C": float(C),
        "penalty": penalty,
        "solver": solver,
        "l1_ratio": None if penalty != "elasticnet" else float(clf_kwargs["l1_ratio"]),
        "n_features": len(features),
        "acc_mean": float(np.mean(accs)),
        "precision_mean": float(np.mean(precs)),
        "recall_mean": float(np.mean(recs)),
        "auc_mean": float(np.mean(aucs)) if aucs else np.nan,
        "acc_splits": accs,
        "auc_splits": aucs,
    }


# --------- Simple grid search ----------
def tune_logreg_timecv(
    df: pd.DataFrame,
    features: list[str],
    target: str = "y_up_1d",
    n_splits: int = 5,
    score: str = "auc",          # "auc" | "acc" | "precision" | "recall"
    topk: int = 10,
):
    # небольшая, но полезная сетка
    grid = []

    # L2 (обычно лучший дефолт)
    for imp in ["mean", "median"]:
        for thr in [0.5, 0.52, 0.55]:
            for C in [0.05, 0.1, 0.3, 1.0, 3.0, 10.0]:
                grid.append(dict(imputer_strategy=imp, thr=thr, C=C, penalty="l2", solver="lbfgs", l1_ratio=None))

    # L1 (saga)
    for imp in ["mean", "median"]:
        for thr in [0.5, 0.52, 0.55]:
            for C in [0.05, 0.1, 0.3, 1.0, 3.0]:
                grid.append(dict(imputer_strategy=imp, thr=thr, C=C, penalty="l1", solver="saga", l1_ratio=None))

    # ElasticNet (saga)
    for imp in ["mean", "median"]:
        for thr in [0.5, 0.52, 0.55]:
            for C in [0.05, 0.1, 0.3, 1.0, 3.0]:
                for l1r in [0.2, 0.5, 0.8]:
                    grid.append(dict(imputer_strategy=imp, thr=thr, C=C, penalty="elasticnet", solver="saga", l1_ratio=l1r))

    rows = []
    for cfg in tqdm(grid):
        try:
            r = walk_forward_logreg_cfg(
                df=df,
                features=features,
                target=target,
                n_splits=n_splits,
                thr=cfg["thr"],
                imputer_strategy=cfg["imputer_strategy"],
                C=cfg["C"],
                penalty=cfg["penalty"],
                solver=cfg["solver"],
                l1_ratio=cfg["l1_ratio"],
            )
            rows.append(r)
        except Exception as e:
            # некоторые комбинации могут падать (редко, но бывает) — просто пропускаем
            continue

    res = pd.DataFrame(rows)

    key = {
        "auc": "auc_mean",
        "acc": "acc_mean",
        "precision": "precision_mean",
        "recall": "recall_mean",
    }[score]

    res = res.sort_values(key, ascending=False).reset_index(drop=True)
    return res.head(topk), res


# -------------------- RUN --------------------
print("BASE feats:", base_feats)
print("LAG  feats:", lag_feats)

top_base, all_base = tune_logreg_timecv(df_all, base_feats, target="y_up_1d", n_splits=5, score="auc", topk=10)
top_lag,  all_lag  = tune_logreg_timecv(df_lag, lag_feats, target="y_up_1d", n_splits=5, score="auc", topk=10)

print("\nTOP BASE by AUC:")
print(top_base[["auc_mean","acc_mean","precision_mean","recall_mean","thr","imputer","penalty","solver","C","l1_ratio","n_features"]])

print("\nTOP LAG by AUC:")
print(top_lag[["auc_mean","acc_mean","precision_mean","recall_mean","thr","imputer","penalty","solver","C","l1_ratio","n_features"]])

# выбираем лучшую конфигурацию по AUC
best_base = top_base.iloc[0].to_dict() if len(top_base) else {"auc_mean": -1}
best_lag = top_lag.iloc[0].to_dict() if len(top_lag) else {"auc_mean": -1}
best = best_base if best_base["auc_mean"] >= best_lag["auc_mean"] else best_lag
print("\nBEST CONFIG:", {k: best[k] for k in ["auc_mean","thr","imputer","penalty","solver","C","l1_ratio"]})
# Out:
# BASE feats: ['feature_spot_price_history__close__pct1', 'feature_spot_price_history__close__diff1', 'feature_open_interest_aggregated__close__pct1', 'feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1', 'feature_global_long_short_account_ratio__global_account_long_percent', 'feature_top_long_short_account_ratio__top_account_long_short_ratio', 'feature_coinbase_premium_index__premium__diff1', 'feature_coinbase_premium_index__premium_abs']
# LAG  feats: ['feature_spot_price_history__close__pct1', 'feature_spot_price_history__close__diff1', 'feature_open_interest_aggregated__close__pct1', 'feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1', 'feature_global_long_short_account_ratio__global_account_long_percent', 'feature_top_long_short_account_ratio__top_account_long_short_ratio', 'feature_coinbase_premium_index__premium__diff1', 'feature_coinbase_premium_index__premium_abs', 'feature_open_interest_aggregated__close__pct1__lag1', 'feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1__lag1', 'feature_global_long_short_account_ratio__global_account_long_percent__lag1', 'feature_top_long_short_account_ratio__top_account_long_short_ratio__lag1', 'feature_coinbase_premium_index__premium__diff1__lag1', 'feature_coinbase_premium_index__premium_abs__lag1', 'feature_open_interest_aggregated__close__pct1__lag2', 'feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1__lag2', 'feature_global_long_short_account_ratio__global_account_long_percent__lag2', 'feature_top_long_short_account_ratio__top_account_long_short_ratio__lag2', 'feature_coinbase_premium_index__premium__diff1__lag2', 'feature_coinbase_premium_index__premium_abs__lag2', 'feature_open_interest_aggregated__close__pct1__lag3', 'feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1__lag3', 'feature_global_long_short_account_ratio__global_account_long_percent__lag3', 'feature_top_long_short_account_ratio__top_account_long_short_ratio__lag3', 'feature_coinbase_premium_index__premium__diff1__lag3', 'feature_coinbase_premium_index__premium_abs__lag3', 'feature_open_interest_aggregated__close__pct1__lag5', 'feature_liquidation_aggregated__aggregated_short_liquidation_usd__diff1__lag5', 'feature_global_long_short_account_ratio__global_account_long_percent__lag5', 'feature_top_long_short_account_ratio__top_account_long_short_ratio__lag5', 'feature_coinbase_premium_index__premium__diff1__lag5', 'feature_coinbase_premium_index__premium_abs__lag5']
# 100%|███████████████████████████████████████████████████████████████| 156/156 [00:09<00:00, 17.04it/s]
# 100%|███████████████████████████████████████████████████████████████| 156/156 [00:23<00:00,  6.54it/s]
# TOP BASE by AUC:
#    auc_mean  acc_mean  precision_mean  recall_mean   thr imputer     penalty  \
# 0  0.550675  0.506024        0.540140     0.616205  0.50    mean          l2
# 1  0.550675  0.524096        0.561864     0.492425  0.52    mean          l2
# 2  0.550675  0.522892        0.591038     0.322780  0.55    mean          l2
# 3  0.550674  0.506024        0.540140     0.616205  0.50  median          l2
# 4  0.550674  0.524096        0.561864     0.492425  0.52  median          l2
# 5  0.550674  0.522892        0.591038     0.322780  0.55  median          l2
# 6  0.549384  0.510843        0.544482     0.630418  0.50    mean  elasticnet
# 7  0.549355  0.520482        0.559504     0.497210  0.52    mean  elasticnet
# 8  0.549355  0.522892        0.587312     0.327610  0.55    mean  elasticnet
# 9  0.549236  0.520482        0.559504     0.497210  0.52  median  elasticnet
#
#   solver    C  l1_ratio  n_features
# 0  lbfgs  0.3       NaN           8
# 1  lbfgs  0.3       NaN           8
# 2  lbfgs  0.3       NaN           8
# 3  lbfgs  0.3       NaN           8
# 4  lbfgs  0.3       NaN           8
# 5  lbfgs  0.3       NaN           8
# 6   saga  1.0       0.5           8
# 7   saga  1.0       0.5           8
# 8   saga  1.0       0.5           8
# 9   saga  1.0       0.5           8
#
# TOP LAG by AUC:
#    auc_mean  acc_mean  precision_mean  recall_mean   thr imputer     penalty  \
# 0  0.520400  0.490361        0.534391     0.136786  0.55    mean  elasticnet
# 1  0.520371  0.495181        0.533713     0.327889  0.52    mean  elasticnet
# 2  0.520371  0.496386        0.527215     0.480095  0.50    mean  elasticnet
# 3  0.520230  0.496386        0.527215     0.480095  0.50  median  elasticnet
# 4  0.520230  0.490361        0.534391     0.136786  0.55  median  elasticnet
# 5  0.520230  0.493976        0.531495     0.325869  0.52  median  elasticnet
# 6  0.516920  0.504819        0.546670     0.465974  0.50  median  elasticnet
# 7  0.516891  0.487952        0.534339     0.187643  0.55  median  elasticnet
# 8  0.516891  0.493976        0.542260     0.330142  0.52  median  elasticnet
# 9  0.516851  0.498795        0.524649     0.528931  0.50    mean          l1
#
#   solver     C  l1_ratio  n_features
# 0   saga  0.10       0.8          32
# 1   saga  0.10       0.8          32
# 2   saga  0.10       0.8          32
# 3   saga  0.10       0.8          32
# 4   saga  0.10       0.8          32
# 5   saga  0.10       0.8          32
# 6   saga  0.05       0.2          32
# 7   saga  0.05       0.2          32
# 8   saga  0.05       0.2          32
# 9   saga  0.10       NaN          32
#
# BEST CONFIG: {'auc_mean': 0.5506752443357067, 'thr': 0.5, 'imputer': 'mean', 'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.3, 'l1_ratio': nan}

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import TimeSeriesSplit
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, accuracy_score


def oos_predictions_logreg(df: pd.DataFrame, features: list[str], target="y_up_1d", n_splits=5):
    d = df.copy()
    d["date"] = pd.to_datetime(d["date"], errors="coerce")
    d = d.sort_values("date", kind="stable").reset_index(drop=True)

    X = d[features].copy()
    y = pd.to_numeric(d[target], errors="coerce")

    m = y.notna() & X.notna().any(axis=1)
    X = X.loc[m].reset_index(drop=True)
    y = y.loc[m].astype(int).reset_index(drop=True)
    dates = d.loc[m, "date"].reset_index(drop=True)

    tscv = TimeSeriesSplit(n_splits=n_splits)

    pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler()),
        ("clf", LogisticRegression(max_iter=3000, class_weight="balanced")),
    ])

    proba_oos = np.full(len(X), np.nan)
    fold_id = np.full(len(X), -1, dtype=int)

    for i, (tr, te) in enumerate(tscv.split(X), start=1):
        pipe.fit(X.iloc[tr], y.iloc[tr])
        p = pipe.predict_proba(X.iloc[te])[:, 1]
        proba_oos[te] = p
        fold_id[te] = i

    out = pd.DataFrame({
        "date": dates,
        "y": y,
        "p_up": proba_oos,
        "fold": fold_id,
    }).dropna(subset=["p_up"]).reset_index(drop=True)

    # общие метрики
    auc = roc_auc_score(out["y"], out["p_up"])
    acc = accuracy_score(out["y"], (out["p_up"] >= 0.5).astype(int))
    return out, auc, acc


def threshold_report(oos: pd.DataFrame, up_thr=0.55, down_thr=0.45):
    # long if p>=up_thr, short if p<=down_thr, else no trade
    p = oos["p_up"]
    y = oos["y"]

    take_long = p >= up_thr
    take_short = p <= down_thr
    take = take_long | take_short

    correct = (take_long & (y == 1)) | (take_short & (y == 0))

    rep = {
        "up_thr": up_thr,
        "down_thr": down_thr,
        "coverage_trades": float(take.mean()),
        "winrate_on_trades": float(correct[take].mean()) if take.any() else np.nan,
        "n_trades": int(take.sum()),
        "n_long": int(take_long.sum()),
        "n_short": int(take_short.sum()),
        "avg_p_up_all": float(p.mean()),
        "avg_p_up_long": float(p[take_long].mean()) if take_long.any() else np.nan,
        "avg_p_up_short": float(p[take_short].mean()) if take_short.any() else np.nan,
    }
    return rep


# ----- run -----
oos, auc, acc = oos_predictions_logreg(df_all, base_feats, n_splits=5)
print("OOS AUC:", auc, "OOS ACC@0.5:", acc)

# попробуем сетку порогов
for up_thr, down_thr in [(0.505, 0.495),(0.51, 0.49),(0.52,0.48),(0.55,0.45),(0.57,0.43),(0.60,0.40), (0.62, 0.38), (0.7, 0.3)]:
    print(threshold_report(oos, up_thr=up_thr, down_thr=down_thr))

# можно посмотреть по фолдам
by_fold = oos.groupby("fold").apply(lambda g: pd.Series({
    "auc": roc_auc_score(g["y"], g["p_up"]) if g["y"].nunique()==2 else np.nan,
    "acc": accuracy_score(g["y"], (g["p_up"]>=0.5).astype(int)),
    "n": len(g)
})).reset_index()
print(by_fold)
# Out:
# OOS AUC: 0.5248213340776535 OOS ACC@0.5: 0.5048192771084338
# {'up_thr': 0.505, 'down_thr': 0.495, 'coverage_trades': 0.9421686746987952, 'winrate_on_trades': 0.5127877237851662, 'n_trades': 782, 'n_long': 485, 'n_short': 297, 'avg_p_up_all': 0.4925057900852324, 'avg_p_up_long': 0.5751273311019216, 'avg_p_up_short': 0.35624658927162167}
# {'up_thr': 0.51, 'down_thr': 0.49, 'coverage_trades': 0.9048192771084337, 'winrate_on_trades': 0.5126498002663116, 'n_trades': 751, 'n_long': 470, 'n_short': 281, 'avg_p_up_all': 0.4925057900852324, 'avg_p_up_long': 0.5772852185483984, 'avg_p_up_short': 0.34850776671492184}
# {'up_thr': 0.52, 'down_thr': 0.48, 'coverage_trades': 0.8024096385542169, 'winrate_on_trades': 0.521021021021021, 'n_trades': 666, 'n_long': 412, 'n_short': 254, 'avg_p_up_all': 0.4925057900852324, 'avg_p_up_long': 0.585955181578879, 'avg_p_up_short': 0.33403918776552616}
# {'up_thr': 0.55, 'down_thr': 0.45, 'coverage_trades': 0.536144578313253, 'winrate_on_trades': 0.5280898876404494, 'n_trades': 445, 'n_long': 260, 'n_short': 185, 'avg_p_up_all': 0.4925057900852324, 'avg_p_up_long': 0.6159731488513388, 'avg_p_up_short': 0.28456555274738365}
# {'up_thr': 0.57, 'down_thr': 0.43, 'coverage_trades': 0.4072289156626506, 'winrate_on_trades': 0.5384615384615384, 'n_trades': 338, 'n_long': 184, 'n_short': 154, 'avg_p_up_all': 0.4925057900852324, 'avg_p_up_long': 0.6386371956794797, 'avg_p_up_short': 0.2532039042252887}
# {'up_thr': 0.6, 'down_thr': 0.4, 'coverage_trades': 0.28674698795180725, 'winrate_on_trades': 0.5210084033613446, 'n_trades': 238, 'n_long': 108, 'n_short': 130, 'avg_p_up_all': 0.4925057900852324, 'avg_p_up_long': 0.67721366684578, 'avg_p_up_short': 0.22318358293347634}
# {'up_thr': 0.62, 'down_thr': 0.38, 'coverage_trades': 0.2493975903614458, 'winrate_on_trades': 0.5265700483091788, 'n_trades': 207, 'n_long': 87, 'n_short': 120, 'avg_p_up_all': 0.4925057900852324, 'avg_p_up_long': 0.6936781835502697, 'avg_p_up_short': 0.20938398217067014}
# {'up_thr': 0.7, 'down_thr': 0.3, 'coverage_trades': 0.14337349397590363, 'winrate_on_trades': 0.4957983193277311, 'n_trades': 119, 'n_long': 30, 'n_short': 89, 'avg_p_up_all': 0.4925057900852324, 'avg_p_up_long': 0.7720518230048008, 'avg_p_up_short': 0.16144454996089697}
#    fold       auc       acc      n
# 0     1  0.583446  0.493976  166.0
# 1     2  0.549251  0.518072  166.0
# 2     3  0.524080  0.512048  166.0
# 3     4  0.529609  0.518072  166.0
# 4     5  0.556817  0.481928  166.0

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, roc_auc_score, accuracy_score

def fold_diagnostics(oos: pd.DataFrame):
    rows = []
    for f, g in oos.groupby("fold"):
        y = g["y"].astype(int).values
        p = g["p_up"].values
        pred = (p >= 0.5).astype(int)

        tn, fp, fn, tp = confusion_matrix(y, pred, labels=[0,1]).ravel()
        rows.append({
            "fold": f,
            "n": len(g),
            "y_mean": float(y.mean()),
            "p_mean": float(np.mean(p)),
            "auc": roc_auc_score(y, p) if len(np.unique(y))==2 else np.nan,
            "acc": accuracy_score(y, pred),
            "pred_pos_rate": float(pred.mean()),
            "TP": int(tp), "FP": int(fp), "TN": int(tn), "FN": int(fn),
        })
    return pd.DataFrame(rows).sort_values("fold").reset_index(drop=True)

print(fold_diagnostics(oos))
print("BASE always-long acc:", float(oos["y"].mean()))
print("BASE always-short acc:", float(1 - oos["y"].mean()))
# Out:
#    fold    n    y_mean    p_mean       auc       acc  pred_pos_rate  TP  FP  \
# 0     1  166  0.596386  0.337826  0.583446  0.493976       0.259036  29  14
# 1     2  166  0.475904  0.539701  0.549251  0.518072       0.680723  56  57
# 2     3  166  0.524096  0.515424  0.524080  0.512048       0.626506  55  49
# 3     4  166  0.524096  0.537091  0.529609  0.518072       0.777108  68  61
# 4     5  166  0.475904  0.532487  0.556817  0.481928       0.765060  60  67
#
#    TN  FN
# 0  53  70
# 1  30  23
# 2  30  32
# 3  18  19
# 4  20  19
# BASE always-long acc: 0.519277108433735
# BASE always-short acc: 0.480722891566265

# %%
from sklearn.metrics import brier_score_loss

print("Brier:", brier_score_loss(oos["y"].astype(int), oos["p_up"]))

# квантильный lift: winrate по бинам вероятности
tmp = oos.copy()
tmp["bin"] = pd.qcut(tmp["p_up"], q=10, duplicates="drop")
lift = tmp.groupby("bin").apply(lambda g: pd.Series({
    "n": len(g),
    "avg_p": g["p_up"].mean(),
    "win_if_long": float((g["y"]==1).mean()),
})).reset_index()
print(lift.sort_values("avg_p"))
# Out:
# Brier: 0.26738283336390367
#                   bin     n     avg_p  win_if_long
# 0  (-0.000711, 0.281]  83.0  0.152346     0.530120
# 1      (0.281, 0.439]  83.0  0.380331     0.506024
# 2      (0.439, 0.478]  83.0  0.460724     0.481928
# 3      (0.478, 0.503]  83.0  0.492013     0.530120
# 4       (0.503, 0.52]  83.0  0.512262     0.433735
# 5       (0.52, 0.535]  83.0  0.526644     0.542169
# 6      (0.535, 0.552]  83.0  0.544264     0.445783
# 7      (0.552, 0.576]  83.0  0.565203     0.481928
# 8      (0.576, 0.624]  83.0  0.594140     0.698795
# 9      (0.624, 0.966]  83.0  0.697131     0.542169

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

def oos_proba_logreg(df: pd.DataFrame, features: list[str], target: str = "y_up_1d", n_splits: int = 5):
    d = df.copy()
    d["date"] = pd.to_datetime(d["date"], errors="coerce")
    d = d.sort_values("date", kind="stable").reset_index(drop=True)

    X = d[features].copy()
    y = pd.to_numeric(d[target], errors="coerce")

    m = y.notna() & X.notna().any(axis=1)
    X, y = X.loc[m].reset_index(drop=True), y.loc[m].astype(int).reset_index(drop=True)

    tscv = TimeSeriesSplit(n_splits=n_splits)

    pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler()),
        ("clf", LogisticRegression(max_iter=3000, class_weight="balanced")),
    ])

    proba_oos = np.full(len(X), np.nan)
    for train_idx, test_idx in tscv.split(X):
        pipe.fit(X.iloc[train_idx], y.iloc[train_idx])
        proba_oos[test_idx] = pipe.predict_proba(X.iloc[test_idx])[:, 1]

    out = pd.DataFrame({"y": y, "p": proba_oos}).dropna()
    return out["y"].values, out["p"].values


def plot_roc(y, p, title="ROC"):
    auc = roc_auc_score(y, p)
    fpr, tpr, _ = roc_curve(y, p)
    plt.figure()
    plt.plot(fpr, tpr, label=f"AUC={auc:.4f}")
    plt.plot([0, 1], [0, 1], linestyle="--", label="random")
    plt.xlabel("FPR")
    plt.ylabel("TPR")
    plt.title(title)
    plt.legend()
    plt.show()
    return auc


y_b, p_b = oos_proba_logreg(df_all, base_feats, n_splits=5)
auc_b = plot_roc(y_b, p_b, title="ROC (BASE, OOS)")

y_l, p_l = oos_proba_logreg(df_lag, lag_feats, n_splits=5)
auc_l = plot_roc(y_l, p_l, title="ROC (LAG, OOS)")

print("AUC BASE:", auc_b)
print("AUC LAG :", auc_l)
# Out:
# AUC BASE: 0.5248213340776535
# AUC LAG : 0.4946996260954009
